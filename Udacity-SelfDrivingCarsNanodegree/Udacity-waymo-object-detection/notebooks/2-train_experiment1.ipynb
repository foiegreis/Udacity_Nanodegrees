# %% [markdown]
# ##2. Train and evaluate reference network with data Augmentation: ssd resnet50, batch 4, momentum 0.8, data augmentation, 25000 runs, lr 0.004
#
# Let's add data augmentation and train a bit longer.
# Also, momentum 0.8 to prevent overfitting and data augmentation in the pipeline_new.config.
#
# ## Analysis:
# Training longer and working on the data augmentation and learning rate improved a lot the process.
#
# (The loss visualization in tensorboard is not that accurate because many checkpoints were deleted based on the keep_max_num parameter in the trainer.py module of the od api.
# We've also modified the model_lib_v2.py file in order to being able to visualize both the train and val data in tensorboard. Please have a look at the files for further information.)
#
# We can infer that the training loss is converging and the test loss is moving in the direction of the train, meaning the model isn't overfitting. Training for more epochs will lead to even better results.
#
# The mAp and recall were increasing, denoting the model was improving during the training. Of course, we could have reached better results training longer.
#
# As you would see in the animation.mp4 file at this link, this was our best result
#
# https://drive.google.com/file/d/1oAYSkN6cecO78yMi_5IbhWXeYVhj7v2z/view?usp=sharing
#
# Here the link to the exported model
#
# https://drive.google.com/drive/folders/1njrHlclFGYtLa-mRV2otzZoy6KqV81sS?usp=sharing

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ##Import libraries

# %%
import sys
sys.path.append('/content/gdrive/MyDrive/GoogleColab/lib')
sys.path.append('/content/gdrive/MyDrive/GoogleColab/lib/models/research/')
sys.path.append('/content/gdrive/MyDrive/GoogleColab/lib/models/research/slim/')
sys.path.append('/content/gdrive/MyDrive/GoogleColab/lib/models/')
sys.path.append('/content/gdrive/MyDrive/GoogleColab/lib/object_detection/')
libs_path = '/content/gdrive/MyDrive/GoogleColab/lib'
# %cd $libs_path
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/lib

# %% [markdown]
# ##Install tf object detection api

# %%
# %cd $libs_path
import os
if 'models' in os.listdir(libs_path):
  # %rm -r models
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/lib
# Cloning into 'models'...
# remote: Enumerating objects: 3336, done.
# remote: Counting objects: 100% (3336/3336), done.
# remote: Compressing objects: 100% (2769/2769), done.
# remote: Total 3336 (delta 880), reused 1436 (delta 517), pack-reused 0
# Receiving objects: 100% (3336/3336), 34.33 MiB | 11.74 MiB/s, done.
# Resolving deltas: 100% (880/880), done.
# Checking out files: 100% (3038/3038), done.

# %% [markdown]
# ## Substitute trainer.py and model_lib_v2.py with my versions
#
#
# **trainer.py line 376**
# - max num checkpoints: None
#
# **model_lib_v2.py line 1136**
# - iterate over checkpoints for evaluation
#
#
# see:
# https://thachngoctran.medium.com/make-tensorflows-object-detection-validation-a-true-post-process-c45785f08d3a

# %% [markdown]
# ##FIND THE MODIFIED SCRIPTS AT THIS LINK FROM MY DRIVE:
#
# https://drive.google.com/file/d/1D6fRZdFjqnM8z3gSxaR7ZrxYcDl_5JW3/view?usp=sharing
# https://drive.google.com/file/d/1FnhgfyEQEMEGDAEzAjSF9GsiUzdqJMZ8/view?usp=sharing
#
# you should download them and upload them in your GoogleColab folder. Otherwise, please update your paths in order to make this work.
#
# #####################################################

# %%
import shutil
path_my_files = '/content/gdrive/MyDrive/GoogleColab/'


path_new_model_lib_v2 = path_my_files + 'model_lib_v2.py'
path_new_trainer = path_my_files + 'trainer.py'

path_original_model_lib_v2 = '/content/gdrive/MyDrive/GoogleColab/lib/models/research/object_detection/model_lib_v2.py'
path_original_trainer = '/content/gdrive/MyDrive/GoogleColab/lib/models/research/object_detection/legacy/trainer.py'


#move the new version in
shutil.copyfile(path_new_model_lib_v2, path_original_model_lib_v2)
shutil.copyfile(path_new_trainer, path_original_trainer)
# Out:
# '/content/gdrive/MyDrive/Colab Notebooks/lib/models/research/object_detection/legacy/trainer.py'

# %%
# %cd $libs_path/models/research/
# !protoc object_detection/protos/*.proto --python_out=.
# Install TensorFlow Object Detection API.
# !cp object_detection/packages/tf2/setup.py .
# !python -m pip install .
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/lib/models/research
# Processing /content/gdrive/MyDrive/Colab Notebooks/lib/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
# Collecting apache-beam
#   Downloading apache_beam-2.38.0-cp37-cp37m-manylinux2010_x86_64.whl (10.2 MB)
#      |████████████████████████████████| 10.2 MB 6.5 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (4.2.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.29.28)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 49.7 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.0.4)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.3.5)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.8.0-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 32.9 MB/s
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.25.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.4 MB)
#      |████████████████████████████████| 23.4 MB 48.7 MB/s
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.8.0)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Collecting py-cpuinfo>=3.3.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 8.3 MB/s
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.0.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 61.2 MB/s
# Collecting tensorflow-text~=2.8.0
#   Downloading tensorflow_text-2.8.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 43.5 MB/s
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.2-py2.py3-none-any.whl (237 kB)
#      |████████████████████████████████| 237 kB 53.7 MB/s
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 51.3 MB/s
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 48.1 MB/s
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: tensorflow~=2.8.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.8.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.21.6)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.8 MB)
#      |████████████████████████████████| 47.8 MB 1.2 MB/s
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.12.11)
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 10.0 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.1 MB/s
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.31.5)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.35.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.17.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.17.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (21.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.23.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2022.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2021.10.8)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (4.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (0.25.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 53.4 MB/s
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (0.5.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.44.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (14.0.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.7)
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.4.11-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 35.9 MB/s
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 48.2 MB/s
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Collecting requests<3.0.0dev,>=2.18.0
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting cloudpickle<3,>=2.0.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.12.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (508 kB)
#      |████████████████████████████████| 508 kB 57.7 MB/s
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Collecting orjson<4.0
#   Downloading orjson-3.6.8-cp37-cp37m-manylinux_2_24_x86_64.whl (253 kB)
#      |████████████████████████████████| 253 kB 55.1 MB/s
# Collecting proto-plus<2,>=1.7.1
#   Downloading proto_plus-1.20.3-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 3.6 MB/s
# Requirement already satisfied: pyarrow<7.0.0,>=0.15.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (6.0.1)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.20.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 56.9 MB/s
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.0.12)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (4.1.2.30)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (1.4.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (0.8.9)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (2019.12.20)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (21.4.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.7.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.16.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Building wheels for collected packages: object-detection, py-cpuinfo, dill, avro-python3, seqeval
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1692736 sha256=acf83cc10f2e8e489d79d8acccaa97ff9e60c6b451c4bf4602246ccd45c022ac
#   Stored in directory: /tmp/pip-ephem-wheel-cache-76jzqj7n/wheels/e9/a3/68/8a5ce16756e32afc910584fa2e9084fc4bb393bdee370bf536
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22257 sha256=f5ea172031bc9325f0dd8d99796d2a0493c76d3ae7014fe876ae6df6534fcfb1
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78544 sha256=b604954ed370091c4d50eeeb1cc9eea65ae97244e8b2c37253417e486c734853
#   Stored in directory: /root/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=44010 sha256=615e1ea5b1f52cd4c4a8330197080c32866bd024866b4fc6f50988844ad11158
#   Stored in directory: /root/.cache/pip/wheels/d6/e5/b1/6b151d9b535ee50aaa6ab27d145a0104b6df02e5636f0376da
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=2084254eb604233bd843fb68b7f160b430a2e1a576cadef4699f99a8284c93c6
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built object-detection py-cpuinfo dill avro-python3 seqeval
# Installing collected packages: requests, protobuf, tf-estimator-nightly, portalocker, dill, colorama, tf-slim, tensorflow-text, tensorflow-model-optimization, tensorflow-addons, seqeval, sentencepiece, sacrebleu, pyyaml, pymongo, py-cpuinfo, proto-plus, orjson, opencv-python-headless, hdfs, fastavro, cloudpickle, tf-models-official, tensorflow-io, lvis, avro-python3, apache-beam, object-detection
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.4
#     Uninstalling dill-0.3.4:
#       Successfully uninstalled dill-0.3.4
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.1.1
#     Uninstalling pymongo-4.1.1:
#       Successfully uninstalled pymongo-4.1.1
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# multiprocess 0.70.12.2 requires dill>=0.3.4, but you have dill 0.3.1.1 which is incompatible.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.0.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed apache-beam-2.38.0 avro-python3-1.10.2 cloudpickle-2.0.0 colorama-0.4.4 dill-0.3.1.1 fastavro-1.4.11 hdfs-2.7.0 lvis-0.5.3 object-detection-0.1 opencv-python-headless-4.5.5.64 orjson-3.6.8 portalocker-2.4.0 proto-plus-1.20.3 protobuf-3.20.1 py-cpuinfo-8.0.0 pymongo-3.12.3 pyyaml-5.4.1 requests-2.27.1 sacrebleu-2.0.0 sentencepiece-0.1.96 seqeval-1.2.2 tensorflow-addons-0.16.1 tensorflow-io-0.25.0 tensorflow-model-optimization-0.7.2 tensorflow-text-2.8.2 tf-estimator-nightly-2.8.0.dev2021122109 tf-models-official-2.8.0 tf-slim-1.1.0

# %%
# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk
# !pip install -q pycocotools
# Out:
# Selecting previously unselected package python-bs4.
# (Reading database ... 155203 files and directories currently installed.)
# Preparing to unpack .../0-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../1-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../2-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../4-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# Preparing to unpack .../5-python-html5lib_0.999999999-1_all.deb ...
# Unpacking python-html5lib (0.999999999-1) ...
# Selecting previously unselected package python-lxml:amd64.
# Preparing to unpack .../6-python-lxml_4.2.1-1ubuntu0.6_amd64.deb ...
# Unpacking python-lxml:amd64 (4.2.1-1ubuntu0.6) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../7-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../8-python-pil_5.1.0-1ubuntu0.7_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1ubuntu0.7) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-bs4 (4.6.0-1) ...
# Setting up python-lxml:amd64 (4.2.1-1ubuntu0.6) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up python-pil:amd64 (5.1.0-1ubuntu0.7) ...
# Setting up python-webencodings (0.5-2) ...
# Setting up python-chardet (3.0.4-1) ...
# Setting up python-html5lib (0.999999999-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
libs_path = '/content/gdrive/MyDrive/GoogleColab/lib'
# !pip3 uninstall opencv-python-headless==4.5.5.62
# !pip3 install --target=$libs_path opencv-python-headless==4.5.2.52
# Out:
# Found existing installation: opencv-python-headless 4.5.5.64
# Uninstalling opencv-python-headless-4.5.5.64:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/cv2/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless-4.5.5.64.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavcodec-65fa80df.so.58.134.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavformat-8ef5c7db.so.58.76.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavutil-9c768859.so.56.70.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libbz2-a273e504.so.1.0.6
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libcrypto-09fe7800.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libgfortran-91cc3cb1.so.3.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libopenblas-r0-f650aae0.3.3.so
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libssl-b92f8066.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libswresample-99364a1c.so.3.9.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libswscale-e6451464.so.5.9.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libvpx-1016051d.so.7.0.0
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libQtCore-bbdab771.so.4.8.7
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libQtGui-903938cd.so.4.8.7
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libQtTest-1183da5d.so.4.8.7
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libavcodec-3cdd3bd4.so.58.62.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libavformat-69a63b50.so.58.35.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libavutil-8e8979a8.so.56.36.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libbz2-7225278b.so.1.0.3
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libcrypto-a25ff511.so.1.1
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libssl-fdf0b66c.so.1.1
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libswresample-c6b3bbb9.so.3.6.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libswscale-2d19f7d1.so.5.6.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libvpx-c887ea55.so.6.1.0
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libz-a147dcb0.so.1.2.3
#     /usr/local/lib/python3.7/dist-packages/cv2/cv2.cpython-37m-x86_64-linux-gnu.so
# Proceed (y/n)? y
#   Successfully uninstalled opencv-python-headless-4.5.5.64
# Collecting opencv-python-headless==4.5.2.52
#   Downloading opencv_python_headless-4.5.2.52-cp37-cp37m-manylinux2014_x86_64.whl (38.2 MB)
#      |████████████████████████████████| 38.2 MB 154 kB/s
# Collecting numpy>=1.14.5
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 23.9 MB/s
# Installing collected packages: numpy, opencv-python-headless
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.0.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.21.6 opencv-python-headless-4.5.2.52
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/numpy-1.21.6.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/opencv_python_headless.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/cv2 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/numpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/opencv_python_headless-4.5.2.52.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/numpy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/bin already exists. Specify --upgrade to force replacement.

# %% [markdown]
# ##Navigate to project folder - set my current paths

# %%
path = '/content/gdrive/MyDrive/GoogleColab'
udacity_path = path + '/UDACITY'
sdc_path = udacity_path + '/SDC'
project_path = sdc_path + '/1-waymo-object-detection'


#Google drive
data_path = project_path + '/data'
waymo_path = data_path + '/waymo'
train_dir = data_path + '/train/'
val_dir = data_path + '/val/'
test_dir = data_path + '/test'
experiments_data = data_path + '/experiments_data'
model_ckpts = experiments_data + '/pretrained_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0'
tfrecord_test = test_dir + 'segment-12200383401366682847_2552_140_2572_140_with_camera_labels.tfrecord'

current_dir = experiments_data + '/experiment1'
pipeline_config_path = current_dir + '/pipeline_new.config'
exported_dir = current_dir + '/exported'
saved_model_dir = exported_dir + '/saved_model'
animation_path = current_dir + '/animation.mp4'

#Github clone
folder_path = project_path + '/Udacity-waymo-object-detection'
workspace_path = folder_path + '/home/workspace'
experiments_path = workspace_path + 'experiments/'
label_map = workspace_path + 'experiments/label_map.pbtxt'

# %%
import tensorflow as tf
print(tf.__version__)

# %%
#test if the imports are correct
# %cd $workspace_path
# !git pull
# !python utils_colab.py

# %% [markdown]
# ##Create pipeline_new.config (do it once)

# %%
'''
#create pipeline_new.config 
# %cd $workspace_path
# !python edit_config.py --train_dir $train_dir --eval_dir $val_dir --batch_size 2 --checkpoint $model_ckpts --label_map $label_map
'''

# %% [markdown]
# ##Set GPU utils

# %%
print("TF GPU: ",tf.test.gpu_device_name())
# !nvcc --version
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0,2,3,4
# Out:
# TF GPU:  /device:GPU:0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0,2,3,4

# %%
# %env CUDA_VISIBLE_DEVICES
# Out:
# '0,2,3,4'

# %%
# %env CUDA_DEVICE_ORDER
# Out:
# 'PCI_BUS_ID'

# %% [markdown]
# ##Start Tensorboard
#
# see https://medium.com/swlh/tensorflow-2-object-detection-api-with-google-colab-b2af171e81cc

# %%
#start Tensorboard
# %load_ext tensorboard
# %tensorboard --logdir=$current_dir

# %% [markdown]
# ![](https://drive.google.com/uc?id=1ZWEX6C8-9NtmEvsco7kkgYJNrqwHnWI1)
#
# ![](https://drive.google.com/uc?id=1LNdlcaU1zm902kKU3otfkuzYu-cdHe29)
#
# ![](https://drive.google.com/uc?id=1lE_tT8PZdLt888tKX3xDkeALwRfqQ5L1)

# %% [markdown]
# ##Paths:
#
# ```
# path = '/content/gdrive/MyDrive/GoogleColab'
# udacity_path = path + '/UDACITY'
# sdc_path = udacity_path + '/SDC'
# project_path = sdc_path + '/1-waymo-object-detection'
#
#
# #Google drive
# data_path = project_path + '/data'
# waymo_path = data_path + '/waymo'
# train_dir = data_path + '/train/'
# val_dir = data_path + '/val/'
# test_dir = data_path + '/test'
# experiments_data = data_path + '/experiments_data'
# model_ckpts = experiments_data + '/pretrained_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0'
# tfrecord_test = test_dir + 'segment-12200383401366682847_2552_140_2572_140_with_camera_labels.tfrecord'
#
# current_dir = experiments_data + '/experiment1'
# pipeline_config_path = current_dir + '/pipeline_new.config'
# exported_dir = current_dir + '/exported'
# saved_model_dir = exported_dir + '/saved_model'
# animation_path = current_dir + '/animation.mp4'
#
# #Github clone
# folder_path = project_path + '/Udacity-waymo-object-detection'
# workspace_path = folder_path + '/home/workspace'
# experiments_path = workspace_path + 'experiments/'
# label_map = workspace_path + 'experiments/label_map.pbtxt'
# ```

# %%
# %cd workspace_path

# %% [markdown]
# ##Train reference model

# %%
# !python model_main_tf2.py --model_dir=$current_dir --pipeline_config_path=$pipeline_config_path
# Out:
# 2022-05-08 22:27:29.896127: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0508 22:27:29.935361 140496611063680 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0508 22:27:30.542975 140496611063680 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0508 22:27:30.543220 140496611063680 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0508 22:27:30.723322 140496611063680 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10153695247769592104_787_000_807_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10023947602400723454_1120_000_1140_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10072140764565668044_4060_000_4080_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10107710434105775874_760_000_780_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10096619443888687526_2820_000_2840_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10017090168044687777_6380_000_6400_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10082223140073588526_6140_000_6160_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10061305430875486848_1080_000_1100_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1022527355599519580_4866_960_4886_960_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10226164909075980558_180_000_200_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10231929575853664160_1160_000_1180_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10206293520369375008_2796_800_2816_800_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10235335145367115211_5420_000_5440_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10275144660749673822_5755_561_5775_561_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10444454289801298640_4360_000_4380_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10455472356147194054_1560_000_1580_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10212406498497081993_5300_000_5320_000_with_camera_labels.tfrecord', '/content/gdrive/MyD ...
# I0508 22:27:31.743004 140496611063680 dataset_builder.py:162] Reading unweighted datasets: ['/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10153695247769592104_787_000_807_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10023947602400723454_1120_000_1140_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10072140764565668044_4060_000_4080_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10107710434105775874_760_000_780_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10096619443888687526_2820_000_2840_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10017090168044687777_6380_000_6400_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10082223140073588526_6140_000_6160_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10061305430875486848_1080_000_1100_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1022527355599519580_4866_960_4886_960_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10226164909075980558_180_000_200_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10231929575853664160_1160_000_1180_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10206293520369375008_2796_800_2816_800_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10235335145367115211_5420_000_5440_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10275144660749673822_5755_561_5775_561_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10444454289801298640_4360_000_4380_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10455472356147194054_1560_000_1580_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10212406498497081993_5300_000_5320_000_with ...
# INFO:tensorflow:Reading record datasets for input file: ['/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10153695247769592104_787_000_807_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10023947602400723454_1120_000_1140_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10072140764565668044_4060_000_4080_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10107710434105775874_760_000_780_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10096619443888687526_2820_000_2840_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10017090168044687777_6380_000_6400_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10082223140073588526_6140_000_6160_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10061305430875486848_1080_000_1100_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1022527355599519580_4866_960_4886_960_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10226164909075980558_180_000_200_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10231929575853664160_1160_000_1180_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10206293520369375008_2796_800_2816_800_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10235335145367115211_5420_000_5440_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10275144660749673822_5755_561_5775_561_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10444454289801298640_4360_000_4380_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10455472356147194054_1560_000_1580_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10212406498497081993_5300_000_5320_000_with_camera_labels.tfrecord', '/content ...
# I0508 22:27:32.680580 140496611063680 dataset_builder.py:79] Reading record datasets for input file: ['/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10153695247769592104_787_000_807_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10023947602400723454_1120_000_1140_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10072140764565668044_4060_000_4080_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10107710434105775874_760_000_780_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10096619443888687526_2820_000_2840_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10017090168044687777_6380_000_6400_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10082223140073588526_6140_000_6160_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10061305430875486848_1080_000_1100_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1022527355599519580_4866_960_4886_960_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10226164909075980558_180_000_200_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10231929575853664160_1160_000_1180_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10206293520369375008_2796_800_2816_800_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10235335145367115211_5420_000_5440_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10275144660749673822_5755_561_5775_561_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10444454289801298640_4360_000_4380_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10455472356147194054_1560_000_1580_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10212406498497081993_5300_000_532 ...
# INFO:tensorflow:Number of filenames to read: 82
# I0508 22:27:32.692022 140496611063680 dataset_builder.py:80] Number of filenames to read: 82
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0508 22:27:32.700573 140496611063680 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0508 22:27:32.739739 140496611063680 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0508 22:27:41.455670 140496611063680 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0508 22:27:45.613998 140496611063680 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# W0508 22:27:48.212925 140496611063680 deprecation.py:547] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0508 22:27:50.320024 140496611063680 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0508 22:28:37.866876 140496611063680 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0508 22:28:37.868318 140496611063680 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0508 22:28:37.870933 140496611063680 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0508 22:28:37.872272 140496611063680 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0508 22:28:37.875093 140496611063680 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0508 22:28:37.876160 140496611063680 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0508 22:28:37.879140 140496611063680 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0508 22:28:37.880216 140496611063680 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0508 22:28:37.882188 140496611063680 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0508 22:28:37.883213 140496611063680 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0508 22:28:39.040386 140491398211328 deprecation.py:547] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.758s
# I0508 22:29:54.621729 140496611063680 model_lib_v2.py:707] Step 100 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.3632149,
#  'Loss/localization_loss': 0.4713768,
#  'Loss/regularization_loss': 0.24436656,
#  'Loss/total_loss': 1.0789583,
#  'learning_rate': 0.00115}
# I0508 22:29:54.622109 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.3632149,
#  'Loss/localization_loss': 0.4713768,
#  'Loss/regularization_loss': 0.24436656,
#  'Loss/total_loss': 1.0789583,
#  'learning_rate': 0.00115}
# INFO:tensorflow:Step 200 per-step time 0.318s
# I0508 22:30:26.143119 140496611063680 model_lib_v2.py:707] Step 200 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.2986851,
#  'Loss/localization_loss': 0.49188176,
#  'Loss/regularization_loss': 0.24431634,
#  'Loss/total_loss': 1.0348833,
#  'learning_rate': 0.0013000001}
# I0508 22:30:26.143649 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.2986851,
#  'Loss/localization_loss': 0.49188176,
#  'Loss/regularization_loss': 0.24431634,
#  'Loss/total_loss': 1.0348833,
#  'learning_rate': 0.0013000001}
# INFO:tensorflow:Step 300 per-step time 0.316s
# I0508 22:30:57.707077 140496611063680 model_lib_v2.py:707] Step 300 per-step time 0.316s
# INFO:tensorflow:{'Loss/classification_loss': 0.2608772,
#  'Loss/localization_loss': 0.46271488,
#  'Loss/regularization_loss': 0.24424776,
#  'Loss/total_loss': 0.96783984,
#  'learning_rate': 0.0014500001}
# I0508 22:30:57.707471 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.2608772,
#  'Loss/localization_loss': 0.46271488,
#  'Loss/regularization_loss': 0.24424776,
#  'Loss/total_loss': 0.96783984,
#  'learning_rate': 0.0014500001}
# INFO:tensorflow:Step 400 per-step time 0.315s
# I0508 22:31:29.185032 140496611063680 model_lib_v2.py:707] Step 400 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.27735102,
#  'Loss/localization_loss': 0.41808283,
#  'Loss/regularization_loss': 0.24417105,
#  'Loss/total_loss': 0.9396049,
#  'learning_rate': 0.0016000001}
# I0508 22:31:29.185377 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.27735102,
#  'Loss/localization_loss': 0.41808283,
#  'Loss/regularization_loss': 0.24417105,
#  'Loss/total_loss': 0.9396049,
#  'learning_rate': 0.0016000001}
# INFO:tensorflow:Step 500 per-step time 0.316s
# I0508 22:32:00.740174 140496611063680 model_lib_v2.py:707] Step 500 per-step time 0.316s
# INFO:tensorflow:{'Loss/classification_loss': 0.38798672,
#  'Loss/localization_loss': 0.68966603,
#  'Loss/regularization_loss': 0.24408023,
#  'Loss/total_loss': 1.3217329,
#  'learning_rate': 0.00175}
# I0508 22:32:00.740559 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.38798672,
#  'Loss/localization_loss': 0.68966603,
#  'Loss/regularization_loss': 0.24408023,
#  'Loss/total_loss': 1.3217329,
#  'learning_rate': 0.00175}
# INFO:tensorflow:Step 600 per-step time 0.316s
# I0508 22:32:32.297474 140496611063680 model_lib_v2.py:707] Step 600 per-step time 0.316s
# INFO:tensorflow:{'Loss/classification_loss': 0.3558557,
#  'Loss/localization_loss': 0.5269609,
#  'Loss/regularization_loss': 0.24400564,
#  'Loss/total_loss': 1.1268222,
#  'learning_rate': 0.0019}
# I0508 22:32:32.297795 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.3558557,
#  'Loss/localization_loss': 0.5269609,
#  'Loss/regularization_loss': 0.24400564,
#  'Loss/total_loss': 1.1268222,
#  'learning_rate': 0.0019}
# INFO:tensorflow:Step 700 per-step time 0.315s
# I0508 22:33:03.806277 140496611063680 model_lib_v2.py:707] Step 700 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.28312317,
#  'Loss/localization_loss': 0.35589737,
#  'Loss/regularization_loss': 0.24392083,
#  'Loss/total_loss': 0.88294137,
#  'learning_rate': 0.0020500002}
# I0508 22:33:03.806621 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.28312317,
#  'Loss/localization_loss': 0.35589737,
#  'Loss/regularization_loss': 0.24392083,
#  'Loss/total_loss': 0.88294137,
#  'learning_rate': 0.0020500002}
# INFO:tensorflow:Step 800 per-step time 0.314s
# I0508 22:33:35.204236 140496611063680 model_lib_v2.py:707] Step 800 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.27090243,
#  'Loss/localization_loss': 0.28825024,
#  'Loss/regularization_loss': 0.24381956,
#  'Loss/total_loss': 0.8029722,
#  'learning_rate': 0.0022}
# I0508 22:33:35.204612 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.27090243,
#  'Loss/localization_loss': 0.28825024,
#  'Loss/regularization_loss': 0.24381956,
#  'Loss/total_loss': 0.8029722,
#  'learning_rate': 0.0022}
# INFO:tensorflow:Step 900 per-step time 0.314s
# I0508 22:34:06.625946 140496611063680 model_lib_v2.py:707] Step 900 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.29107267,
#  'Loss/localization_loss': 0.3337677,
#  'Loss/regularization_loss': 0.24372292,
#  'Loss/total_loss': 0.8685633,
#  'learning_rate': 0.0023500002}
# I0508 22:34:06.626284 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.29107267,
#  'Loss/localization_loss': 0.3337677,
#  'Loss/regularization_loss': 0.24372292,
#  'Loss/total_loss': 0.8685633,
#  'learning_rate': 0.0023500002}
# INFO:tensorflow:Step 1000 per-step time 0.316s
# I0508 22:34:38.191065 140496611063680 model_lib_v2.py:707] Step 1000 per-step time 0.316s
# INFO:tensorflow:{'Loss/classification_loss': 0.24702656,
#  'Loss/localization_loss': 0.31875643,
#  'Loss/regularization_loss': 0.2436339,
#  'Loss/total_loss': 0.8094169,
#  'learning_rate': 0.0025}
# I0508 22:34:38.191401 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.24702656,
#  'Loss/localization_loss': 0.31875643,
#  'Loss/regularization_loss': 0.2436339,
#  'Loss/total_loss': 0.8094169,
#  'learning_rate': 0.0025}
# INFO:tensorflow:Step 1100 per-step time 0.315s
# I0508 22:35:09.642123 140496611063680 model_lib_v2.py:707] Step 1100 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.19111215,
#  'Loss/localization_loss': 0.21306057,
#  'Loss/regularization_loss': 0.2435197,
#  'Loss/total_loss': 0.64769244,
#  'learning_rate': 0.0026500002}
# I0508 22:35:09.642577 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.19111215,
#  'Loss/localization_loss': 0.21306057,
#  'Loss/regularization_loss': 0.2435197,
#  'Loss/total_loss': 0.64769244,
#  'learning_rate': 0.0026500002}
# INFO:tensorflow:Step 1200 per-step time 0.315s
# I0508 22:35:41.168496 140496611063680 model_lib_v2.py:707] Step 1200 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.19827422,
#  'Loss/localization_loss': 0.29586205,
#  'Loss/regularization_loss': 0.24343196,
#  'Loss/total_loss': 0.73756826,
#  'learning_rate': 0.0028000001}
# I0508 22:35:41.168823 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.19827422,
#  'Loss/localization_loss': 0.29586205,
#  'Loss/regularization_loss': 0.24343196,
#  'Loss/total_loss': 0.73756826,
#  'learning_rate': 0.0028000001}
# INFO:tensorflow:Step 1300 per-step time 0.315s
# I0508 22:36:12.642197 140496611063680 model_lib_v2.py:707] Step 1300 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.30180466,
#  'Loss/localization_loss': 0.35584843,
#  'Loss/regularization_loss': 0.24333414,
#  'Loss/total_loss': 0.90098727,
#  'learning_rate': 0.00295}
# I0508 22:36:12.642580 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.30180466,
#  'Loss/localization_loss': 0.35584843,
#  'Loss/regularization_loss': 0.24333414,
#  'Loss/total_loss': 0.90098727,
#  'learning_rate': 0.00295}
# INFO:tensorflow:Step 1400 per-step time 0.314s
# I0508 22:36:44.036886 140496611063680 model_lib_v2.py:707] Step 1400 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.26986563,
#  'Loss/localization_loss': 0.308707,
#  'Loss/regularization_loss': 0.24322096,
#  'Loss/total_loss': 0.82179356,
#  'learning_rate': 0.0031000003}
# I0508 22:36:44.037239 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.26986563,
#  'Loss/localization_loss': 0.308707,
#  'Loss/regularization_loss': 0.24322096,
#  'Loss/total_loss': 0.82179356,
#  'learning_rate': 0.0031000003}
# INFO:tensorflow:Step 1500 per-step time 0.316s
# I0508 22:37:15.668080 140496611063680 model_lib_v2.py:707] Step 1500 per-step time 0.316s
# INFO:tensorflow:{'Loss/classification_loss': 0.22919495,
#  'Loss/localization_loss': 0.2602157,
#  'Loss/regularization_loss': 0.24312732,
#  'Loss/total_loss': 0.732538,
#  'learning_rate': 0.00325}
# I0508 22:37:15.668507 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.22919495,
#  'Loss/localization_loss': 0.2602157,
#  'Loss/regularization_loss': 0.24312732,
#  'Loss/total_loss': 0.732538,
#  'learning_rate': 0.00325}
# INFO:tensorflow:Step 1600 per-step time 0.313s
# I0508 22:37:47.004635 140496611063680 model_lib_v2.py:707] Step 1600 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.20547055,
#  'Loss/localization_loss': 0.27543136,
#  'Loss/regularization_loss': 0.24302001,
#  'Loss/total_loss': 0.7239219,
#  'learning_rate': 0.0034000003}
# I0508 22:37:47.005089 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.20547055,
#  'Loss/localization_loss': 0.27543136,
#  'Loss/regularization_loss': 0.24302001,
#  'Loss/total_loss': 0.7239219,
#  'learning_rate': 0.0034000003}
# INFO:tensorflow:Step 1700 per-step time 0.315s
# I0508 22:38:18.520352 140496611063680 model_lib_v2.py:707] Step 1700 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.20983934,
#  'Loss/localization_loss': 0.29682234,
#  'Loss/regularization_loss': 0.24292645,
#  'Loss/total_loss': 0.74958813,
#  'learning_rate': 0.00355}
# I0508 22:38:18.520746 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.20983934,
#  'Loss/localization_loss': 0.29682234,
#  'Loss/regularization_loss': 0.24292645,
#  'Loss/total_loss': 0.74958813,
#  'learning_rate': 0.00355}
# INFO:tensorflow:Step 1800 per-step time 0.315s
# I0508 22:38:49.978259 140496611063680 model_lib_v2.py:707] Step 1800 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.23188262,
#  'Loss/localization_loss': 0.30346072,
#  'Loss/regularization_loss': 0.24284306,
#  'Loss/total_loss': 0.77818644,
#  'learning_rate': 0.0037000002}
# I0508 22:38:49.978698 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.23188262,
#  'Loss/localization_loss': 0.30346072,
#  'Loss/regularization_loss': 0.24284306,
#  'Loss/total_loss': 0.77818644,
#  'learning_rate': 0.0037000002}
# INFO:tensorflow:Step 1900 per-step time 0.315s
# I0508 22:39:21.476378 140496611063680 model_lib_v2.py:707] Step 1900 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.21340415,
#  'Loss/localization_loss': 0.32426903,
#  'Loss/regularization_loss': 0.24281676,
#  'Loss/total_loss': 0.7804899,
#  'learning_rate': 0.00385}
# I0508 22:39:21.476757 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.21340415,
#  'Loss/localization_loss': 0.32426903,
#  'Loss/regularization_loss': 0.24281676,
#  'Loss/total_loss': 0.7804899,
#  'learning_rate': 0.00385}
# INFO:tensorflow:Step 2000 per-step time 0.315s
# I0508 22:39:52.966504 140496611063680 model_lib_v2.py:707] Step 2000 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.23467043,
#  'Loss/localization_loss': 0.3450684,
#  'Loss/regularization_loss': 0.24280809,
#  'Loss/total_loss': 0.82254696,
#  'learning_rate': 0.004}
# I0508 22:39:52.966845 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.23467043,
#  'Loss/localization_loss': 0.3450684,
#  'Loss/regularization_loss': 0.24280809,
#  'Loss/total_loss': 0.82254696,
#  'learning_rate': 0.004}
# INFO:tensorflow:Step 2100 per-step time 0.327s
# I0508 22:40:25.710112 140496611063680 model_lib_v2.py:707] Step 2100 per-step time 0.327s
# INFO:tensorflow:{'Loss/classification_loss': 0.308541,
#  'Loss/localization_loss': 0.4256985,
#  'Loss/regularization_loss': 0.24278398,
#  'Loss/total_loss': 0.9770234,
#  'learning_rate': 0.003999814}
# I0508 22:40:25.710475 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.308541,
#  'Loss/localization_loss': 0.4256985,
#  'Loss/regularization_loss': 0.24278398,
#  'Loss/total_loss': 0.9770234,
#  'learning_rate': 0.003999814}
# INFO:tensorflow:Step 2200 per-step time 0.315s
# I0508 22:40:57.206829 140496611063680 model_lib_v2.py:707] Step 2200 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.21678837,
#  'Loss/localization_loss': 0.3093823,
#  'Loss/regularization_loss': 0.24265903,
#  'Loss/total_loss': 0.7688297,
#  'learning_rate': 0.0039992537}
# I0508 22:40:57.207172 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.21678837,
#  'Loss/localization_loss': 0.3093823,
#  'Loss/regularization_loss': 0.24265903,
#  'Loss/total_loss': 0.7688297,
#  'learning_rate': 0.0039992537}
# INFO:tensorflow:Step 2300 per-step time 0.315s
# I0508 22:41:28.681406 140496611063680 model_lib_v2.py:707] Step 2300 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.23081882,
#  'Loss/localization_loss': 0.23039316,
#  'Loss/regularization_loss': 0.24252456,
#  'Loss/total_loss': 0.70373654,
#  'learning_rate': 0.003998321}
# I0508 22:41:28.681834 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.23081882,
#  'Loss/localization_loss': 0.23039316,
#  'Loss/regularization_loss': 0.24252456,
#  'Loss/total_loss': 0.70373654,
#  'learning_rate': 0.003998321}
# INFO:tensorflow:Step 2400 per-step time 0.315s
# I0508 22:42:00.223030 140496611063680 model_lib_v2.py:707] Step 2400 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.2459719,
#  'Loss/localization_loss': 0.3645438,
#  'Loss/regularization_loss': 0.24249329,
#  'Loss/total_loss': 0.853009,
#  'learning_rate': 0.0039970158}
# I0508 22:42:00.223367 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.2459719,
#  'Loss/localization_loss': 0.3645438,
#  'Loss/regularization_loss': 0.24249329,
#  'Loss/total_loss': 0.853009,
#  'learning_rate': 0.0039970158}
# INFO:tensorflow:Step 2500 per-step time 0.315s
# I0508 22:42:31.733811 140496611063680 model_lib_v2.py:707] Step 2500 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.29590285,
#  'Loss/localization_loss': 0.30169618,
#  'Loss/regularization_loss': 0.24237932,
#  'Loss/total_loss': 0.83997834,
#  'learning_rate': 0.0039953375}
# I0508 22:42:31.734189 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.29590285,
#  'Loss/localization_loss': 0.30169618,
#  'Loss/regularization_loss': 0.24237932,
#  'Loss/total_loss': 0.83997834,
#  'learning_rate': 0.0039953375}
# INFO:tensorflow:Step 2600 per-step time 0.315s
# I0508 22:43:03.271492 140496611063680 model_lib_v2.py:707] Step 2600 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.33436793,
#  'Loss/localization_loss': 0.4190897,
#  'Loss/regularization_loss': 0.24232781,
#  'Loss/total_loss': 0.9957855,
#  'learning_rate': 0.003993287}
# I0508 22:43:03.271900 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.33436793,
#  'Loss/localization_loss': 0.4190897,
#  'Loss/regularization_loss': 0.24232781,
#  'Loss/total_loss': 0.9957855,
#  'learning_rate': 0.003993287}
# INFO:tensorflow:Step 2700 per-step time 0.315s
# I0508 22:43:34.771491 140496611063680 model_lib_v2.py:707] Step 2700 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.2630516,
#  'Loss/localization_loss': 0.2755575,
#  'Loss/regularization_loss': 0.24225368,
#  'Loss/total_loss': 0.78086275,
#  'learning_rate': 0.0039908653}
# I0508 22:43:34.771848 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.2630516,
#  'Loss/localization_loss': 0.2755575,
#  'Loss/regularization_loss': 0.24225368,
#  'Loss/total_loss': 0.78086275,
#  'learning_rate': 0.0039908653}
# INFO:tensorflow:Step 2800 per-step time 0.314s
# I0508 22:44:06.172742 140496611063680 model_lib_v2.py:707] Step 2800 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.23168494,
#  'Loss/localization_loss': 0.27493986,
#  'Loss/regularization_loss': 0.24216169,
#  'Loss/total_loss': 0.7487865,
#  'learning_rate': 0.003988072}
# I0508 22:44:06.173079 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.23168494,
#  'Loss/localization_loss': 0.27493986,
#  'Loss/regularization_loss': 0.24216169,
#  'Loss/total_loss': 0.7487865,
#  'learning_rate': 0.003988072}
# INFO:tensorflow:Step 2900 per-step time 0.315s
# I0508 22:44:37.635724 140496611063680 model_lib_v2.py:707] Step 2900 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.23477033,
#  'Loss/localization_loss': 0.37154102,
#  'Loss/regularization_loss': 0.24207659,
#  'Loss/total_loss': 0.8483879,
#  'learning_rate': 0.0039849067}
# I0508 22:44:37.636095 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.23477033,
#  'Loss/localization_loss': 0.37154102,
#  'Loss/regularization_loss': 0.24207659,
#  'Loss/total_loss': 0.8483879,
#  'learning_rate': 0.0039849067}
# INFO:tensorflow:Step 3000 per-step time 0.314s
# I0508 22:45:09.063256 140496611063680 model_lib_v2.py:707] Step 3000 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.24488086,
#  'Loss/localization_loss': 0.37619776,
#  'Loss/regularization_loss': 0.2419652,
#  'Loss/total_loss': 0.8630438,
#  'learning_rate': 0.003981372}
# I0508 22:45:09.063701 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.24488086,
#  'Loss/localization_loss': 0.37619776,
#  'Loss/regularization_loss': 0.2419652,
#  'Loss/total_loss': 0.8630438,
#  'learning_rate': 0.003981372}
# INFO:tensorflow:Step 3100 per-step time 0.314s
# I0508 22:45:40.497127 140496611063680 model_lib_v2.py:707] Step 3100 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.21582536,
#  'Loss/localization_loss': 0.26133528,
#  'Loss/regularization_loss': 0.24189088,
#  'Loss/total_loss': 0.7190515,
#  'learning_rate': 0.0039774673}
# I0508 22:45:40.497523 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.21582536,
#  'Loss/localization_loss': 0.26133528,
#  'Loss/regularization_loss': 0.24189088,
#  'Loss/total_loss': 0.7190515,
#  'learning_rate': 0.0039774673}
# INFO:tensorflow:Step 3200 per-step time 0.316s
# I0508 22:46:12.113850 140496611063680 model_lib_v2.py:707] Step 3200 per-step time 0.316s
# INFO:tensorflow:{'Loss/classification_loss': 0.2390555,
#  'Loss/localization_loss': 0.31096146,
#  'Loss/regularization_loss': 0.2418525,
#  'Loss/total_loss': 0.79186946,
#  'learning_rate': 0.003973194}
# I0508 22:46:12.114191 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.2390555,
#  'Loss/localization_loss': 0.31096146,
#  'Loss/regularization_loss': 0.2418525,
#  'Loss/total_loss': 0.79186946,
#  'learning_rate': 0.003973194}
# INFO:tensorflow:Step 3300 per-step time 0.315s
# I0508 22:46:43.586380 140496611063680 model_lib_v2.py:707] Step 3300 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.19450203,
#  'Loss/localization_loss': 0.2108445,
#  'Loss/regularization_loss': 0.24178171,
#  'Loss/total_loss': 0.6471282,
#  'learning_rate': 0.003968552}
# I0508 22:46:43.586728 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.19450203,
#  'Loss/localization_loss': 0.2108445,
#  'Loss/regularization_loss': 0.24178171,
#  'Loss/total_loss': 0.6471282,
#  'learning_rate': 0.003968552}
# INFO:tensorflow:Step 3400 per-step time 0.312s
# I0508 22:47:14.823706 140496611063680 model_lib_v2.py:707] Step 3400 per-step time 0.312s
# INFO:tensorflow:{'Loss/classification_loss': 0.32168743,
#  'Loss/localization_loss': 0.3347962,
#  'Loss/regularization_loss': 0.24170363,
#  'Loss/total_loss': 0.8981873,
#  'learning_rate': 0.0039635436}
# I0508 22:47:14.824060 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.32168743,
#  'Loss/localization_loss': 0.3347962,
#  'Loss/regularization_loss': 0.24170363,
#  'Loss/total_loss': 0.8981873,
#  'learning_rate': 0.0039635436}
# INFO:tensorflow:Step 3500 per-step time 0.314s
# I0508 22:47:46.230092 140496611063680 model_lib_v2.py:707] Step 3500 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.32521975,
#  'Loss/localization_loss': 0.35054174,
#  'Loss/regularization_loss': 0.24165893,
#  'Loss/total_loss': 0.9174204,
#  'learning_rate': 0.0039581684}
# I0508 22:47:46.230426 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.32521975,
#  'Loss/localization_loss': 0.35054174,
#  'Loss/regularization_loss': 0.24165893,
#  'Loss/total_loss': 0.9174204,
#  'learning_rate': 0.0039581684}
# INFO:tensorflow:Step 3600 per-step time 0.315s
# I0508 22:48:17.760778 140496611063680 model_lib_v2.py:707] Step 3600 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.26607096,
#  'Loss/localization_loss': 0.35671648,
#  'Loss/regularization_loss': 0.24155802,
#  'Loss/total_loss': 0.8643455,
#  'learning_rate': 0.003952428}
# I0508 22:48:17.761089 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.26607096,
#  'Loss/localization_loss': 0.35671648,
#  'Loss/regularization_loss': 0.24155802,
#  'Loss/total_loss': 0.8643455,
#  'learning_rate': 0.003952428}
# INFO:tensorflow:Step 3700 per-step time 0.315s
# I0508 22:48:49.232204 140496611063680 model_lib_v2.py:707] Step 3700 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.1979699,
#  'Loss/localization_loss': 0.20678572,
#  'Loss/regularization_loss': 0.24150807,
#  'Loss/total_loss': 0.6462637,
#  'learning_rate': 0.003946323}
# I0508 22:48:49.232567 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.1979699,
#  'Loss/localization_loss': 0.20678572,
#  'Loss/regularization_loss': 0.24150807,
#  'Loss/total_loss': 0.6462637,
#  'learning_rate': 0.003946323}
# INFO:tensorflow:Step 3800 per-step time 0.314s
# I0508 22:49:20.635837 140496611063680 model_lib_v2.py:707] Step 3800 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.16543412,
#  'Loss/localization_loss': 0.18511473,
#  'Loss/regularization_loss': 0.24160524,
#  'Loss/total_loss': 0.5921541,
#  'learning_rate': 0.003939855}
# I0508 22:49:20.636195 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.16543412,
#  'Loss/localization_loss': 0.18511473,
#  'Loss/regularization_loss': 0.24160524,
#  'Loss/total_loss': 0.5921541,
#  'learning_rate': 0.003939855}
# INFO:tensorflow:Step 3900 per-step time 0.313s
# ...
# I0509 00:26:24.130747 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.13931532,
#  'Loss/localization_loss': 0.13379218,
#  'Loss/regularization_loss': 0.22258595,
#  'Loss/total_loss': 0.49569345,
#  'learning_rate': 0.0001344756}
# INFO:tensorflow:Step 22400 per-step time 0.313s
# I0509 00:26:55.440004 140496611063680 model_lib_v2.py:707] Step 22400 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.18336892,
#  'Loss/localization_loss': 0.18631306,
#  'Loss/regularization_loss': 0.22257459,
#  'Loss/total_loss': 0.59225655,
#  'learning_rate': 0.000124802}
# I0509 00:26:55.440375 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.18336892,
#  'Loss/localization_loss': 0.18631306,
#  'Loss/regularization_loss': 0.22257459,
#  'Loss/total_loss': 0.59225655,
#  'learning_rate': 0.000124802}
# INFO:tensorflow:Step 22500 per-step time 0.314s
# I0509 00:27:26.834592 140496611063680 model_lib_v2.py:707] Step 22500 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.33842313,
#  'Loss/localization_loss': 0.3436454,
#  'Loss/regularization_loss': 0.22256443,
#  'Loss/total_loss': 0.9046329,
#  'learning_rate': 0.00011547805}
# I0509 00:27:26.834917 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.33842313,
#  'Loss/localization_loss': 0.3436454,
#  'Loss/regularization_loss': 0.22256443,
#  'Loss/total_loss': 0.9046329,
#  'learning_rate': 0.00011547805}
# INFO:tensorflow:Step 22600 per-step time 0.314s
# I0509 00:27:58.263622 140496611063680 model_lib_v2.py:707] Step 22600 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.14692271,
#  'Loss/localization_loss': 0.20718864,
#  'Loss/regularization_loss': 0.22255452,
#  'Loss/total_loss': 0.5766659,
#  'learning_rate': 0.000106505875}
# I0509 00:27:58.264032 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.14692271,
#  'Loss/localization_loss': 0.20718864,
#  'Loss/regularization_loss': 0.22255452,
#  'Loss/total_loss': 0.5766659,
#  'learning_rate': 0.000106505875}
# INFO:tensorflow:Step 22700 per-step time 0.313s
# I0509 00:28:29.566236 140496611063680 model_lib_v2.py:707] Step 22700 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.15656905,
#  'Loss/localization_loss': 0.16035978,
#  'Loss/regularization_loss': 0.22254585,
#  'Loss/total_loss': 0.53947467,
#  'learning_rate': 9.7887045e-05}
# I0509 00:28:29.566568 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.15656905,
#  'Loss/localization_loss': 0.16035978,
#  'Loss/regularization_loss': 0.22254585,
#  'Loss/total_loss': 0.53947467,
#  'learning_rate': 9.7887045e-05}
# INFO:tensorflow:Step 22800 per-step time 0.313s
# I0509 00:29:00.866176 140496611063680 model_lib_v2.py:707] Step 22800 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.14613372,
#  'Loss/localization_loss': 0.16295026,
#  'Loss/regularization_loss': 0.22253773,
#  'Loss/total_loss': 0.5316217,
#  'learning_rate': 8.962286e-05}
# I0509 00:29:00.866524 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.14613372,
#  'Loss/localization_loss': 0.16295026,
#  'Loss/regularization_loss': 0.22253773,
#  'Loss/total_loss': 0.5316217,
#  'learning_rate': 8.962286e-05}
# INFO:tensorflow:Step 22900 per-step time 0.311s
# I0509 00:29:31.992377 140496611063680 model_lib_v2.py:707] Step 22900 per-step time 0.311s
# INFO:tensorflow:{'Loss/classification_loss': 0.1441679,
#  'Loss/localization_loss': 0.17478713,
#  'Loss/regularization_loss': 0.22253022,
#  'Loss/total_loss': 0.54148525,
#  'learning_rate': 8.171523e-05}
# I0509 00:29:31.992765 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.1441679,
#  'Loss/localization_loss': 0.17478713,
#  'Loss/regularization_loss': 0.22253022,
#  'Loss/total_loss': 0.54148525,
#  'learning_rate': 8.171523e-05}
# INFO:tensorflow:Step 23000 per-step time 0.313s
# I0509 00:30:03.247258 140496611063680 model_lib_v2.py:707] Step 23000 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.15021107,
#  'Loss/localization_loss': 0.13479055,
#  'Loss/regularization_loss': 0.22252333,
#  'Loss/total_loss': 0.50752497,
#  'learning_rate': 7.4165466e-05}
# I0509 00:30:03.247635 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.15021107,
#  'Loss/localization_loss': 0.13479055,
#  'Loss/regularization_loss': 0.22252333,
#  'Loss/total_loss': 0.50752497,
#  'learning_rate': 7.4165466e-05}
# INFO:tensorflow:Step 23100 per-step time 0.312s
# I0509 00:30:34.484252 140496611063680 model_lib_v2.py:707] Step 23100 per-step time 0.312s
# INFO:tensorflow:{'Loss/classification_loss': 0.16715333,
#  'Loss/localization_loss': 0.2481832,
#  'Loss/regularization_loss': 0.22251728,
#  'Loss/total_loss': 0.63785386,
#  'learning_rate': 6.697476e-05}
# I0509 00:30:34.484587 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.16715333,
#  'Loss/localization_loss': 0.2481832,
#  'Loss/regularization_loss': 0.22251728,
#  'Loss/total_loss': 0.63785386,
#  'learning_rate': 6.697476e-05}
# INFO:tensorflow:Step 23200 per-step time 0.313s
# I0509 00:31:05.815284 140496611063680 model_lib_v2.py:707] Step 23200 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.20805366,
#  'Loss/localization_loss': 0.19699636,
#  'Loss/regularization_loss': 0.22251172,
#  'Loss/total_loss': 0.62756175,
#  'learning_rate': 6.0145143e-05}
# I0509 00:31:05.815651 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.20805366,
#  'Loss/localization_loss': 0.19699636,
#  'Loss/regularization_loss': 0.22251172,
#  'Loss/total_loss': 0.62756175,
#  'learning_rate': 6.0145143e-05}
# INFO:tensorflow:Step 23300 per-step time 0.314s
# I0509 00:31:37.232727 140496611063680 model_lib_v2.py:707] Step 23300 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.19518223,
#  'Loss/localization_loss': 0.23334228,
#  'Loss/regularization_loss': 0.2225068,
#  'Loss/total_loss': 0.6510313,
#  'learning_rate': 5.3677202e-05}
# I0509 00:31:37.233124 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.19518223,
#  'Loss/localization_loss': 0.23334228,
#  'Loss/regularization_loss': 0.2225068,
#  'Loss/total_loss': 0.6510313,
#  'learning_rate': 5.3677202e-05}
# INFO:tensorflow:Step 23400 per-step time 0.313s
# I0509 00:32:08.566577 140496611063680 model_lib_v2.py:707] Step 23400 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.14049512,
#  'Loss/localization_loss': 0.08381024,
#  'Loss/regularization_loss': 0.22250217,
#  'Loss/total_loss': 0.44680753,
#  'learning_rate': 4.757226e-05}
# I0509 00:32:08.566918 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.14049512,
#  'Loss/localization_loss': 0.08381024,
#  'Loss/regularization_loss': 0.22250217,
#  'Loss/total_loss': 0.44680753,
#  'learning_rate': 4.757226e-05}
# INFO:tensorflow:Step 23500 per-step time 0.314s
# I0509 00:32:39.925329 140496611063680 model_lib_v2.py:707] Step 23500 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.13857758,
#  'Loss/localization_loss': 0.14927332,
#  'Loss/regularization_loss': 0.2224982,
#  'Loss/total_loss': 0.5103491,
#  'learning_rate': 4.1831852e-05}
# I0509 00:32:39.925703 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.13857758,
#  'Loss/localization_loss': 0.14927332,
#  'Loss/regularization_loss': 0.2224982,
#  'Loss/total_loss': 0.5103491,
#  'learning_rate': 4.1831852e-05}
# INFO:tensorflow:Step 23600 per-step time 0.313s
# I0509 00:33:11.221729 140496611063680 model_lib_v2.py:707] Step 23600 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.17555946,
#  'Loss/localization_loss': 0.19597444,
#  'Loss/regularization_loss': 0.22249474,
#  'Loss/total_loss': 0.59402865,
#  'learning_rate': 3.6456466e-05}
# I0509 00:33:11.222084 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.17555946,
#  'Loss/localization_loss': 0.19597444,
#  'Loss/regularization_loss': 0.22249474,
#  'Loss/total_loss': 0.59402865,
#  'learning_rate': 3.6456466e-05}
# INFO:tensorflow:Step 23700 per-step time 0.313s
# I0509 00:33:42.530281 140496611063680 model_lib_v2.py:707] Step 23700 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.1782784,
#  'Loss/localization_loss': 0.29254228,
#  'Loss/regularization_loss': 0.2224919,
#  'Loss/total_loss': 0.6933126,
#  'learning_rate': 3.144765e-05}
# I0509 00:33:42.530616 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.1782784,
#  'Loss/localization_loss': 0.29254228,
#  'Loss/regularization_loss': 0.2224919,
#  'Loss/total_loss': 0.6933126,
#  'learning_rate': 3.144765e-05}
# INFO:tensorflow:Step 23800 per-step time 0.313s
# I0509 00:34:13.824929 140496611063680 model_lib_v2.py:707] Step 23800 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.15851702,
#  'Loss/localization_loss': 0.15201984,
#  'Loss/regularization_loss': 0.22248933,
#  'Loss/total_loss': 0.5330262,
#  'learning_rate': 2.6806236e-05}
# I0509 00:34:13.825268 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.15851702,
#  'Loss/localization_loss': 0.15201984,
#  'Loss/regularization_loss': 0.22248933,
#  'Loss/total_loss': 0.5330262,
#  'learning_rate': 2.6806236e-05}
# INFO:tensorflow:Step 23900 per-step time 0.314s
# I0509 00:34:45.227372 140496611063680 model_lib_v2.py:707] Step 23900 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.14245193,
#  'Loss/localization_loss': 0.1462295,
#  'Loss/regularization_loss': 0.22248718,
#  'Loss/total_loss': 0.5111686,
#  'learning_rate': 2.2532584e-05}
# I0509 00:34:45.227735 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.14245193,
#  'Loss/localization_loss': 0.1462295,
#  'Loss/regularization_loss': 0.22248718,
#  'Loss/total_loss': 0.5111686,
#  'learning_rate': 2.2532584e-05}
# INFO:tensorflow:Step 24000 per-step time 0.313s
# I0509 00:35:16.570349 140496611063680 model_lib_v2.py:707] Step 24000 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.15588346,
#  'Loss/localization_loss': 0.1801445,
#  'Loss/regularization_loss': 0.22248532,
#  'Loss/total_loss': 0.5585133,
#  'learning_rate': 1.8628121e-05}
# I0509 00:35:16.570754 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.15588346,
#  'Loss/localization_loss': 0.1801445,
#  'Loss/regularization_loss': 0.22248532,
#  'Loss/total_loss': 0.5585133,
#  'learning_rate': 1.8628121e-05}
# INFO:tensorflow:Step 24100 per-step time 0.328s
# I0509 00:35:49.327730 140496611063680 model_lib_v2.py:707] Step 24100 per-step time 0.328s
# INFO:tensorflow:{'Loss/classification_loss': 0.16933914,
#  'Loss/localization_loss': 0.17212413,
#  'Loss/regularization_loss': 0.22248387,
#  'Loss/total_loss': 0.56394714,
#  'learning_rate': 1.5093208e-05}
# I0509 00:35:49.328080 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.16933914,
#  'Loss/localization_loss': 0.17212413,
#  'Loss/regularization_loss': 0.22248387,
#  'Loss/total_loss': 0.56394714,
#  'learning_rate': 1.5093208e-05}
# INFO:tensorflow:Step 24200 per-step time 0.315s
# I0509 00:36:20.779350 140496611063680 model_lib_v2.py:707] Step 24200 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.17386422,
#  'Loss/localization_loss': 0.17856951,
#  'Loss/regularization_loss': 0.22248267,
#  'Loss/total_loss': 0.5749164,
#  'learning_rate': 1.1928678e-05}
# I0509 00:36:20.779715 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.17386422,
#  'Loss/localization_loss': 0.17856951,
#  'Loss/regularization_loss': 0.22248267,
#  'Loss/total_loss': 0.5749164,
#  'learning_rate': 1.1928678e-05}
# INFO:tensorflow:Step 24300 per-step time 0.313s
# I0509 00:36:52.060029 140496611063680 model_lib_v2.py:707] Step 24300 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.19115774,
#  'Loss/localization_loss': 0.20911808,
#  'Loss/regularization_loss': 0.22248173,
#  'Loss/total_loss': 0.62275755,
#  'learning_rate': 9.135008e-06}
# I0509 00:36:52.060380 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.19115774,
#  'Loss/localization_loss': 0.20911808,
#  'Loss/regularization_loss': 0.22248173,
#  'Loss/total_loss': 0.62275755,
#  'learning_rate': 9.135008e-06}
# INFO:tensorflow:Step 24400 per-step time 0.312s
# I0509 00:37:23.228924 140496611063680 model_lib_v2.py:707] Step 24400 per-step time 0.312s
# INFO:tensorflow:{'Loss/classification_loss': 0.12373587,
#  'Loss/localization_loss': 0.11618723,
#  'Loss/regularization_loss': 0.2224808,
#  'Loss/total_loss': 0.4624039,
#  'learning_rate': 6.7127944e-06}
# I0509 00:37:23.229272 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.12373587,
#  'Loss/localization_loss': 0.11618723,
#  'Loss/regularization_loss': 0.2224808,
#  'Loss/total_loss': 0.4624039,
#  'learning_rate': 6.7127944e-06}
# INFO:tensorflow:Step 24500 per-step time 0.313s
# I0509 00:37:54.527488 140496611063680 model_lib_v2.py:707] Step 24500 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.23558065,
#  'Loss/localization_loss': 0.17479889,
#  'Loss/regularization_loss': 0.2224803,
#  'Loss/total_loss': 0.6328598,
#  'learning_rate': 4.6623945e-06}
# I0509 00:37:54.527857 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.23558065,
#  'Loss/localization_loss': 0.17479889,
#  'Loss/regularization_loss': 0.2224803,
#  'Loss/total_loss': 0.6328598,
#  'learning_rate': 4.6623945e-06}
# INFO:tensorflow:Step 24600 per-step time 0.314s
# I0509 00:38:25.951484 140496611063680 model_lib_v2.py:707] Step 24600 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.15445554,
#  'Loss/localization_loss': 0.18429117,
#  'Loss/regularization_loss': 0.22247997,
#  'Loss/total_loss': 0.5612267,
#  'learning_rate': 2.9844048e-06}
# I0509 00:38:25.951812 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.15445554,
#  'Loss/localization_loss': 0.18429117,
#  'Loss/regularization_loss': 0.22247997,
#  'Loss/total_loss': 0.5612267,
#  'learning_rate': 2.9844048e-06}
# INFO:tensorflow:Step 24700 per-step time 0.315s
# I0509 00:38:57.490228 140496611063680 model_lib_v2.py:707] Step 24700 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.18778238,
#  'Loss/localization_loss': 0.21277367,
#  'Loss/regularization_loss': 0.22247976,
#  'Loss/total_loss': 0.6230358,
#  'learning_rate': 1.6789437e-06}
# I0509 00:38:57.490597 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.18778238,
#  'Loss/localization_loss': 0.21277367,
#  'Loss/regularization_loss': 0.22247976,
#  'Loss/total_loss': 0.6230358,
#  'learning_rate': 1.6789437e-06}
# INFO:tensorflow:Step 24800 per-step time 0.314s
# I0509 00:39:28.939270 140496611063680 model_lib_v2.py:707] Step 24800 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.16931136,
#  'Loss/localization_loss': 0.17352137,
#  'Loss/regularization_loss': 0.22247967,
#  'Loss/total_loss': 0.5653124,
#  'learning_rate': 7.462502e-07}
# I0509 00:39:28.939607 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.16931136,
#  'Loss/localization_loss': 0.17352137,
#  'Loss/regularization_loss': 0.22247967,
#  'Loss/total_loss': 0.5653124,
#  'learning_rate': 7.462502e-07}
# INFO:tensorflow:Step 24900 per-step time 0.313s
# I0509 00:40:00.288322 140496611063680 model_lib_v2.py:707] Step 24900 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.1430632,
#  'Loss/localization_loss': 0.20247687,
#  'Loss/regularization_loss': 0.22247963,
#  'Loss/total_loss': 0.5680197,
#  'learning_rate': 1.8656254e-07}
# I0509 00:40:00.288672 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.1430632,
#  'Loss/localization_loss': 0.20247687,
#  'Loss/regularization_loss': 0.22247963,
#  'Loss/total_loss': 0.5680197,
#  'learning_rate': 1.8656254e-07}
# INFO:tensorflow:Step 25000 per-step time 0.313s
# I0509 00:40:31.633533 140496611063680 model_lib_v2.py:707] Step 25000 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.14997186,
#  'Loss/localization_loss': 0.17741606,
#  'Loss/regularization_loss': 0.22247963,
#  'Loss/total_loss': 0.5498676,
#  'learning_rate': 0.0}
# I0509 00:40:31.633893 140496611063680 model_lib_v2.py:708] {'Loss/classification_loss': 0.14997186,
#  'Loss/localization_loss': 0.17741606,
#  'Loss/regularization_loss': 0.22247963,
#  'Loss/total_loss': 0.5498676,
#  'learning_rate': 0.0}

# %% [markdown]
# ##Validation

# %%
# !python model_main_tf2.py --model_dir=$current_dir --pipeline_config_path=$pipeline_config_path --checkpoint_dir=$current_dir
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0509 00:41:46.580925 140197951186816 model_lib_v2.py:1090] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0509 00:41:46.581232 140197951186816 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0509 00:41:46.581332 140197951186816 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0509 00:41:46.581425 140197951186816 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0509 00:41:46.581600 140197951186816 model_lib_v2.py:1110] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2022-05-09 00:41:47.355778: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Reading unweighted datasets: ['/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10094743350625019937_3420_000_3440_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10075870402459732738_1060_000_1080_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10241508783381919015_2889_360_2909_360_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10584247114982259878_490_000_510_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-1051897962568538022_238_170_258_170_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-1083056852838271990_4080_000_4100_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11070802577416161387_740_000_760_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11355519273066561009_5323_000_5343_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11252086830380107152_1540_000_1560_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11392401368700458296_1086_429_1106_429_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11918003324473417938_1400_000_1420_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11925224148023145510_1040_000_1060_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-12179768245749640056_5561_070_5581_070_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11971497357570544465_1200_000_1220_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-12161824480686739258_1813_380_1833_380_with_camera_labels.tfrecord']
# I0509 00:41:47.545837 140197951186816 dataset_builder.py:162] Reading unweighted datasets: ['/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10094743350625019937_3420_000_3440_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10075870402459732738_1060_000_1080_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10241508783381919015_2889_360_2909_360_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10584247114982259878_490_000_510_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-1051897962568538022_238_170_258_170_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-1083056852838271990_4080_000_4100_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11070802577416161387_740_000_760_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11355519273066561009_5323_000_5343_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11252086830380107152_1540_000_1560_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11392401368700458296_1086_429_1106_429_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11918003324473417938_1400_000_1420_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11925224148023145510_1040_000_1060_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-12179768245749640056_5561_070_5581_070_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11971497357570544465_1200_000_1220_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-12161824480686739258_1813_380_1833_380_with_camera_labels.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10094743350625019937_3420_000_3440_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10075870402459732738_1060_000_1080_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10241508783381919015_2889_360_2909_360_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10584247114982259878_490_000_510_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-1051897962568538022_238_170_258_170_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-1083056852838271990_4080_000_4100_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11070802577416161387_740_000_760_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11355519273066561009_5323_000_5343_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11252086830380107152_1540_000_1560_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11392401368700458296_1086_429_1106_429_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11918003324473417938_1400_000_1420_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11925224148023145510_1040_000_1060_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-12179768245749640056_5561_070_5581_070_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11971497357570544465_1200_000_1220_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-12161824480686739258_1813_380_1833_380_with_camera_labels.tfrecord']
# I0509 00:41:48.037644 140197951186816 dataset_builder.py:79] Reading record datasets for input file: ['/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10094743350625019937_3420_000_3440_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10075870402459732738_1060_000_1080_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10241508783381919015_2889_360_2909_360_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-10584247114982259878_490_000_510_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-1051897962568538022_238_170_258_170_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-1083056852838271990_4080_000_4100_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11070802577416161387_740_000_760_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11355519273066561009_5323_000_5343_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11252086830380107152_1540_000_1560_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11392401368700458296_1086_429_1106_429_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11918003324473417938_1400_000_1420_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11925224148023145510_1040_000_1060_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-12179768245749640056_5561_070_5581_070_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-11971497357570544465_1200_000_1220_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/val/segment-12161824480686739258_1813_380_1833_380_with_camera_labels.tfrecord']
# INFO:tensorflow:Number of filenames to read: 15
# I0509 00:41:48.037941 140197951186816 dataset_builder.py:80] Number of filenames to read: 15
# WARNING:tensorflow:num_readers has been reduced to 15 to match input file shards.
# W0509 00:41:48.038051 140197951186816 dataset_builder.py:87] num_readers has been reduced to 15 to match input file shards.
# WARNING:tensorflow:`shuffle` is false, but the input data stream is still slightly shuffled since `num_readers` > 1.
# W0509 00:41:48.039823 140197951186816 dataset_builder.py:93] `shuffle` is false, but the input data stream is still slightly shuffled since `num_readers` > 1.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0509 00:41:48.041147 140197951186816 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0509 00:41:48.066977 140197951186816 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0509 00:41:52.710223 140197951186816 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0509 00:41:54.047863 140197951186816 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0509 00:42:27.805669 140197951186816 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0509 00:42:27.933747 140197951186816 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0509 00:42:28.081346 140197951186816 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I0509 00:42:39.442579 140197951186816 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0509 00:42:47.304302 140197951186816 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Performing evaluation on 298 images.
# I0509 00:42:55.096524 140197951186816 coco_evaluation.py:293] Performing evaluation on 298 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0509 00:42:55.101143 140197951186816 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.02s)
# I0509 00:42:55.116612 140197951186816 coco_tools.py:138] DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.57s).
# Accumulating evaluation results...
# DONE (t=0.33s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.352
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.140
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.430
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.539
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.159
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.239
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.157
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.504
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.600
# INFO:tensorflow:Eval metrics at step 12000
# I0509 00:43:09.055330 140197951186816 model_lib_v2.py:1015] Eval metrics at step 12000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.167380
# I0509 00:43:09.130340 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.167380
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.352008
# I0509 00:43:09.132365 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.352008
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.140129
# I0509 00:43:09.136047 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.140129
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.081133
# I0509 00:43:09.138121 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.081133
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.430440
# I0509 00:43:09.139820 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.430440
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.539346
# I0509 00:43:09.141319 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.539346
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.032652
# I0509 00:43:09.142818 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.032652
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.159131
# I0509 00:43:09.144315 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.159131
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.238768
# I0509 00:43:09.145807 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.238768
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.157083
# I0509 00:43:09.147295 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.157083
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.503768
# I0509 00:43:09.148833 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.503768
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.599719
# I0509 00:43:09.150508 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.599719
# INFO:tensorflow:	+ Loss/localization_loss: 0.369435
# I0509 00:43:09.151717 140197951186816 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.369435
# INFO:tensorflow:	+ Loss/classification_loss: 0.248768
# I0509 00:43:09.152954 140197951186816 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.248768
# INFO:tensorflow:	+ Loss/regularization_loss: 0.230397
# I0509 00:43:09.154163 140197951186816 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.230397
# INFO:tensorflow:	+ Loss/total_loss: 0.848601
# I0509 00:43:09.155387 140197951186816 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.848601
# INFO:tensorflow:Finished eval step 0
# I0509 00:43:18.176059 140197951186816 model_lib_v2.py:966] Finished eval step 0
# INFO:tensorflow:Finished eval step 100
# I0509 00:43:29.420460 140197951186816 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0509 00:43:37.254676 140197951186816 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Performing evaluation on 298 images.
# I0509 00:43:53.303515 140197951186816 coco_evaluation.py:293] Performing evaluation on 298 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0509 00:43:53.309046 140197951186816 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.02s)
# I0509 00:43:53.327143 140197951186816 coco_tools.py:138] DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.05s).
# Accumulating evaluation results...
# DONE (t=0.32s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.354
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.137
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.442
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.555
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.160
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.236
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.153
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.508
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.597
# INFO:tensorflow:Eval metrics at step 14000
# I0509 00:44:06.728914 140197951186816 model_lib_v2.py:1015] Eval metrics at step 14000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.167483
# I0509 00:44:06.748861 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.167483
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.354109
# I0509 00:44:06.750895 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.354109
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.137241
# I0509 00:44:06.752467 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.137241
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.077800
# I0509 00:44:06.754003 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.077800
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.441788
# I0509 00:44:06.755549 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.441788
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.555220
# I0509 00:44:06.757065 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.555220
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.033101
# I0509 00:44:06.758654 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.033101
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.160342
# I0509 00:44:06.760195 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.160342
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.235611
# I0509 00:44:06.761746 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.235611
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.152864
# I0509 00:44:06.763295 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.152864
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.508228
# I0509 00:44:06.764888 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.508228
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.596688
# I0509 00:44:06.766905 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.596688
# INFO:tensorflow:	+ Loss/localization_loss: 0.379501
# I0509 00:44:06.768060 140197951186816 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.379501
# INFO:tensorflow:	+ Loss/classification_loss: 0.242953
# I0509 00:44:06.769184 140197951186816 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.242953
# INFO:tensorflow:	+ Loss/regularization_loss: 0.227812
# I0509 00:44:06.770338 140197951186816 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.227812
# INFO:tensorflow:	+ Loss/total_loss: 0.850266
# I0509 00:44:06.771504 140197951186816 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.850266
# INFO:tensorflow:Finished eval step 0
# I0509 00:44:14.292029 140197951186816 model_lib_v2.py:966] Finished eval step 0
# INFO:tensorflow:Finished eval step 100
# I0509 00:44:25.657189 140197951186816 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0509 00:44:33.535627 140197951186816 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Performing evaluation on 298 images.
# I0509 00:44:41.380081 140197951186816 coco_evaluation.py:293] Performing evaluation on 298 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0509 00:44:41.385321 140197951186816 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.02s)
# I0509 00:44:41.403478 140197951186816 coco_tools.py:138] DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=12.32s).
# Accumulating evaluation results...
# DONE (t=0.33s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.144
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.243
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.156
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.539
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.616
# INFO:tensorflow:Eval metrics at step 16000
# I0509 00:44:54.085565 140197951186816 model_lib_v2.py:1015] Eval metrics at step 16000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.170762
# I0509 00:44:54.105569 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.170762
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.358190
# I0509 00:44:54.107623 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.358190
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.144038
# I0509 00:44:54.109322 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.144038
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.078455
# I0509 00:44:54.110902 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.078455
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.449117
# I0509 00:44:54.112520 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.449117
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.564031
# I0509 00:44:54.114316 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.564031
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.034337
# I0509 00:44:54.116008 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.034337
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.163639
# I0509 00:44:54.117643 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.163639
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.242787
# I0509 00:44:54.119197 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.242787
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.155637
# I0509 00:44:54.120780 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.155637
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.538577
# I0509 00:44:54.122804 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.538577
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.615953
# I0509 00:44:54.124619 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.615953
# INFO:tensorflow:	+ Loss/localization_loss: 0.368904
# I0509 00:44:54.125855 140197951186816 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.368904
# INFO:tensorflow:	+ Loss/classification_loss: 0.258301
# I0509 00:44:54.127133 140197951186816 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.258301
# INFO:tensorflow:	+ Loss/regularization_loss: 0.225714
# I0509 00:44:54.128462 140197951186816 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.225714
# INFO:tensorflow:	+ Loss/total_loss: 0.852919
# I0509 00:44:54.129731 140197951186816 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.852919
# INFO:tensorflow:Finished eval step 0
# I0509 00:45:01.654917 140197951186816 model_lib_v2.py:966] Finished eval step 0
# INFO:tensorflow:Finished eval step 100
# I0509 00:45:12.965441 140197951186816 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0509 00:45:20.802746 140197951186816 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Performing evaluation on 298 images.
# I0509 00:45:28.536785 140197951186816 coco_evaluation.py:293] Performing evaluation on 298 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0509 00:45:28.542254 140197951186816 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.02s)
# I0509 00:45:28.558158 140197951186816 coco_tools.py:138] DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=12.52s).
# Accumulating evaluation results...
# DONE (t=0.33s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.181
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.377
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.573
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.170
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.544
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.619
# INFO:tensorflow:Eval metrics at step 18000
# I0509 00:45:41.443851 140197951186816 model_lib_v2.py:1015] Eval metrics at step 18000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.181133
# I0509 00:45:41.462895 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.181133
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.376917
# I0509 00:45:41.464673 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.376917
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.149285
# I0509 00:45:41.466098 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.149285
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.088423
# I0509 00:45:41.467422 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.088423
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.461884
# I0509 00:45:41.468775 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.461884
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.572996
# I0509 00:45:41.470094 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.572996
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.034783
# I0509 00:45:41.471527 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.034783
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.170448
# I0509 00:45:41.472905 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.170448
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.251862
# I0509 00:45:41.474307 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.251862
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.165169
# I0509 00:45:41.475782 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.165169
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.544462
# I0509 00:45:41.477246 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.544462
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.619498
# I0509 00:45:41.478777 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.619498
# INFO:tensorflow:	+ Loss/localization_loss: 0.364737
# I0509 00:45:41.479857 140197951186816 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.364737
# INFO:tensorflow:	+ Loss/classification_loss: 0.231807
# I0509 00:45:41.480950 140197951186816 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.231807
# INFO:tensorflow:	+ Loss/regularization_loss: 0.224121
# I0509 00:45:41.482104 140197951186816 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.224121
# INFO:tensorflow:	+ Loss/total_loss: 0.820665
# I0509 00:45:41.483211 140197951186816 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.820665
# INFO:tensorflow:Finished eval step 0
# I0509 00:45:49.105737 140197951186816 model_lib_v2.py:966] Finished eval step 0
# INFO:tensorflow:Finished eval step 100
# I0509 00:46:00.195140 140197951186816 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0509 00:46:07.919244 140197951186816 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Performing evaluation on 298 images.
# I0509 00:46:15.149899 140197951186816 coco_evaluation.py:293] Performing evaluation on 298 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0509 00:46:15.155037 140197951186816 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.02s)
# I0509 00:46:15.172286 140197951186816 coco_tools.py:138] DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=12.36s).
# Accumulating evaluation results...
# DONE (t=0.32s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.181
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.377
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.465
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.541
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.615
# INFO:tensorflow:Eval metrics at step 20000
# I0509 00:46:27.883582 140197951186816 model_lib_v2.py:1015] Eval metrics at step 20000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.180861
# I0509 00:46:27.902475 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.180861
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.376988
# I0509 00:46:27.904394 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.376988
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.149828
# I0509 00:46:27.905758 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.149828
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.089231
# I0509 00:46:27.907088 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.089231
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.465480
# I0509 00:46:27.908422 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.465480
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.567493
# I0509 00:46:27.909786 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.567493
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.034329
# I0509 00:46:27.911096 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.034329
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.170550
# I0509 00:46:27.912487 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.170550
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.254025
# I0509 00:46:27.913916 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.254025
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.168493
# I0509 00:46:27.915313 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.168493
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.540627
# I0509 00:46:27.916682 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.540627
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.614822
# I0509 00:46:27.918180 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.614822
# INFO:tensorflow:	+ Loss/localization_loss: 0.368234
# I0509 00:46:27.919253 140197951186816 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.368234
# INFO:tensorflow:	+ Loss/classification_loss: 0.235965
# I0509 00:46:27.920335 140197951186816 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.235965
# INFO:tensorflow:	+ Loss/regularization_loss: 0.223123
# I0509 00:46:27.921419 140197951186816 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.223123
# INFO:tensorflow:	+ Loss/total_loss: 0.827322
# I0509 00:46:27.922526 140197951186816 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.827322
# INFO:tensorflow:Finished eval step 0
# I0509 00:46:35.538278 140197951186816 model_lib_v2.py:966] Finished eval step 0
# INFO:tensorflow:Finished eval step 100
# I0509 00:46:46.942325 140197951186816 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0509 00:46:54.954745 140197951186816 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Performing evaluation on 298 images.
# I0509 00:47:02.496106 140197951186816 coco_evaluation.py:293] Performing evaluation on 298 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0509 00:47:02.501212 140197951186816 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.02s)
# I0509 00:47:02.517575 140197951186816 coco_tools.py:138] DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=12.39s).
# Accumulating evaluation results...
# DONE (t=0.32s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.182
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.379
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.541
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.616
# INFO:tensorflow:Eval metrics at step 22000
# I0509 00:47:15.258096 140197951186816 model_lib_v2.py:1015] Eval metrics at step 22000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.182156
# I0509 00:47:15.277828 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.182156
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.379331
# I0509 00:47:15.279872 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.379331
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.150496
# I0509 00:47:15.281472 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.150496
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.090108
# I0509 00:47:15.283053 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.090108
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.467992
# I0509 00:47:15.284559 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.467992
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.567723
# I0509 00:47:15.285960 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.567723
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.034897
# I0509 00:47:15.287330 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.034897
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.170678
# I0509 00:47:15.288876 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.170678
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.252649
# I0509 00:47:15.290356 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.252649
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.166892
# I0509 00:47:15.291735 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.166892
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.540580
# I0509 00:47:15.293092 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.540580
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.616012
# I0509 00:47:15.294640 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.616012
# INFO:tensorflow:	+ Loss/localization_loss: 0.362633
# I0509 00:47:15.295763 140197951186816 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.362633
# INFO:tensorflow:	+ Loss/classification_loss: 0.238486
# I0509 00:47:15.296920 140197951186816 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.238486
# INFO:tensorflow:	+ Loss/regularization_loss: 0.222625
# I0509 00:47:15.297999 140197951186816 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.222625
# INFO:tensorflow:	+ Loss/total_loss: 0.823744
# I0509 00:47:15.299086 140197951186816 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.823744
# INFO:tensorflow:Finished eval step 0
# I0509 00:47:23.011914 140197951186816 model_lib_v2.py:966] Finished eval step 0
# INFO:tensorflow:Finished eval step 100
# I0509 00:47:34.402904 140197951186816 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0509 00:47:42.243479 140197951186816 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Performing evaluation on 298 images.
# I0509 00:47:49.966606 140197951186816 coco_evaluation.py:293] Performing evaluation on 298 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0509 00:47:49.971746 140197951186816 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.02s)
# I0509 00:47:49.987891 140197951186816 coco_tools.py:138] DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=12.29s).
# Accumulating evaluation results...
# DONE (t=0.32s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.182
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.380
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.152
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.539
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.620
# INFO:tensorflow:Eval metrics at step 24000
# I0509 00:48:02.626536 140197951186816 model_lib_v2.py:1015] Eval metrics at step 24000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.182447
# I0509 00:48:02.646841 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.182447
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.379687
# I0509 00:48:02.648983 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.379687
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.152026
# I0509 00:48:02.650404 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.152026
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.089379
# I0509 00:48:02.651802 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.089379
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.469233
# I0509 00:48:02.653228 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.469233
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.570929
# I0509 00:48:02.654690 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.570929
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.034580
# I0509 00:48:02.656103 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.034580
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.171741
# I0509 00:48:02.657485 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.171741
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.252768
# I0509 00:48:02.658815 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.252768
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.167052
# I0509 00:48:02.660171 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.167052
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.539283
# I0509 00:48:02.661545 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.539283
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.619531
# I0509 00:48:02.663184 140197951186816 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.619531
# INFO:tensorflow:	+ Loss/localization_loss: 0.361652
# I0509 00:48:02.664332 140197951186816 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.361652
# INFO:tensorflow:	+ Loss/classification_loss: 0.232754
# I0509 00:48:02.665482 140197951186816 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.232754
# INFO:tensorflow:	+ Loss/regularization_loss: 0.222485
# I0509 00:48:02.666744 140197951186816 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.222485
# INFO:tensorflow:	+ Loss/total_loss: 0.816891
# I0509 00:48:02.667936 140197951186816 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.816891

# %% [markdown]
# # Export model
#
# export the model

# %%
#create exported directory
# !mkdir $output_directory

# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path $pipeline_config_path --trained_checkpoint_dir $current_dir --output_directory $exported_dir
# Out:
# 2022-05-09 00:54:12.892595: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0509 00:54:13.063939 140195433731968 deprecation.py:615] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# 2022-05-09 00:54:34.014396: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f80b46fb190>, because it is not built.
# W0509 00:54:37.900587 140195433731968 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f80b46fb190>, because it is not built.
# W0509 00:55:00.481496 140195433731968 save.py:265] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 208). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/experiments_data/experiment1/exported/saved_model/assets
# I0509 00:55:08.542936 140195433731968 builder_impl.py:780] Assets written to: /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/experiments_data/experiment1/exported/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/experiments_data/experiment1/exported/pipeline.config
# I0509 00:55:09.257469 140195433731968 config_util.py:254] Writing pipeline config file to /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/experiments_data/experiment1/exported/pipeline.config

# %% [markdown]
# ## Exporting animation
#
# we create a video on the test set to assess performances

# %%
# %cd ..

# %%
# !python inference_video.py --labelmap_path $label_map --model_path $saved_model_dir  --tf_record_path $tfrecord_test --config_path $pipeline_config_path --output_path $animation_path
# Out:
# 2022-05-09 01:12:00,938 INFO     Loading model from /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/experiments_data/experiment1/exported/saved_model
# 2022-05-09 01:12:02.225970: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-05-09 01:12:16,203 INFO     Loading config from experiments/experiment1/pipeline_new.config
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# 2022-05-09 01:12:18,685 INFO     Inference on /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/test/segment-12200383401366682847_2552_140_2572_140_with_camera_labels.tfrecord
# 2022-05-09 01:12:18,798 INFO     Step: 0
# 2022-05-09 01:12:22,603 INFO     Step: 10
# 2022-05-09 01:12:23,260 INFO     Step: 20
# 2022-05-09 01:12:23,917 INFO     Step: 30
# 2022-05-09 01:12:24,572 INFO     Step: 40
# 2022-05-09 01:12:25,153 INFO     Step: 50
# 2022-05-09 01:12:25,736 INFO     Step: 60
# 2022-05-09 01:12:26,313 INFO     Step: 70
# 2022-05-09 01:12:26,892 INFO     Step: 80
# 2022-05-09 01:12:27,454 INFO     Step: 90
# 2022-05-09 01:12:28,009 INFO     Step: 100
# 2022-05-09 01:12:28,601 INFO     Step: 110
# 2022-05-09 01:12:29,200 INFO     Step: 120
# 2022-05-09 01:12:29,773 INFO     Step: 130
# 2022-05-09 01:12:30,335 INFO     Step: 140
# 2022-05-09 01:12:30,937 INFO     Step: 150
# 2022-05-09 01:12:31,571 INFO     Step: 160
# 2022-05-09 01:12:32,254 INFO     Step: 170
# 2022-05-09 01:12:32,926 INFO     Step: 180
# 2022-05-09 01:12:33,591 INFO     Step: 190
