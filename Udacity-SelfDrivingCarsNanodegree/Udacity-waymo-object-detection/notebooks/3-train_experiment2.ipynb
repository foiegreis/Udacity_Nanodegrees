# %% [markdown]
# ## 3. Train and evaluate reference network with data Augmentation: ssd resnet50, batch 4, momentum 0.9, data augmentation, 30000 runs, lr 0.079 with decay,
# changes from the original model in:
# - batch non max suppression
# - convolutional box predictor
# - dropout
#
# see:
#
# - https://neptune.ai/blog/tensorflow-object-detection-api-best-practices-to-training-evaluation-deployment
#
#
# ##Analysis:
#
# Our chances on batch_non_max_suppression and convolutional_box_predictor performed poorly on our dataset, even if we tried to tailor the hyperparameters in order to take under consideration the infos we got from the eda process.
# However, given the loss curves for train and eval, the dropout stage was performing well and we should keep it in future models.
#
# Here's the animation - look how the boxes do not cover the entire vehicle area!
# https://drive.google.com/file/d/1eBdaPGyxyVahNsSDSSpNjYq7TN7Ltd8f/view?usp=sharing
#
# link to the saved model
#
# https://drive.google.com/drive/folders/1d8hCchhA7cnEkycW1Oy4QnhIu-j8Dg_6?usp=sharing

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ##Import libraries

# %%
import sys
sys.path.append('/content/gdrive/MyDrive/GoogleColab/lib')
sys.path.append('/content/gdrive/MyDrive/GoogleColab/lib/models/research/')
sys.path.append('/content/gdrive/MyDrive/GoogleColab/lib/models/research/slim/')
sys.path.append('/content/gdrive/MyDrive/GoogleColab/lib/models/')
sys.path.append('/content/gdrive/MyDrive/GoogleColab/lib/object_detection/')
libs_path = '/content/gdrive/MyDrive/GoogleColab/lib'
# %cd $libs_path

# %% [markdown]
# ##Install tf object detection api

# %%
# %cd $libs_path
import os
if 'models' in os.listdir(libs_path):
  # %rm -r models
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/lib
# Cloning into 'models'...
# remote: Enumerating objects: 3336, done.
# remote: Counting objects: 100% (3336/3336), done.
# remote: Compressing objects: 100% (2769/2769), done.
# remote: Total 3336 (delta 880), reused 1435 (delta 517), pack-reused 0
# Receiving objects: 100% (3336/3336), 34.33 MiB | 16.55 MiB/s, done.
# Resolving deltas: 100% (880/880), done.
# Checking out files: 100% (3038/3038), done.

# %% [markdown]
# ## Substitute trainer.py and model_lib_v2.py with my versions
#
#
# **trainer.py line 376**
# - max num checkpoints: None
#
# **model_lib_v2.py line 1136**
# - iterate over checkpoints for evaluation
#
#
# see:
# https://thachngoctran.medium.com/make-tensorflows-object-detection-validation-a-true-post-process-c45785f08d3a

# %% [markdown]
# ##FIND THE MODIFIED SCRIPTS AT THIS LINK FROM MY DRIVE:
#
# https://drive.google.com/file/d/1D6fRZdFjqnM8z3gSxaR7ZrxYcDl_5JW3/view?usp=sharing
# https://drive.google.com/file/d/1FnhgfyEQEMEGDAEzAjSF9GsiUzdqJMZ8/view?usp=sharing
#
# you should download them and upload them in your GoogleColab folder. Otherwise, please update your paths in order to make this work.
#
# #####################################################

# %%
import shutil
path_my_files = '/content/gdrive/MyDrive/GoogleColab/'


path_new_model_lib_v2 = path_my_files + 'model_lib_v2.py'
path_new_trainer = path_my_files + 'trainer.py'

path_original_model_lib_v2 = '/content/gdrive/MyDrive/GoogleColab/lib/models/research/object_detection/model_lib_v2.py'
path_original_trainer = '/content/gdrive/MyDrive/GoogleColab/lib/models/research/object_detection/legacy/trainer.py'


#move the new version in
shutil.copyfile(path_new_model_lib_v2, path_original_model_lib_v2)
shutil.copyfile(path_new_trainer, path_original_trainer)
# Out:
# '/content/gdrive/MyDrive/Colab Notebooks/lib/models/research/object_detection/legacy/trainer.py'

# %%
# %cd $libs_path/models/research/
# !protoc object_detection/protos/*.proto --python_out=.
# Install TensorFlow Object Detection API.
# !cp object_detection/packages/tf2/setup.py .
# !python -m pip install .
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/lib/models/research
# Processing /content/gdrive/MyDrive/Colab Notebooks/lib/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
# Collecting apache-beam
#   Downloading apache_beam-2.38.0-cp37-cp37m-manylinux2010_x86_64.whl (10.2 MB)
#      |████████████████████████████████| 10.2 MB 24.3 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (4.2.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.29.28)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 79.0 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.0.4)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.3.5)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.8.0-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 72.2 MB/s
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.25.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.4 MB)
#      |████████████████████████████████| 23.4 MB 1.3 MB/s
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.8.0)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Requirement already satisfied: tensorflow~=2.8.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.8.0)
# Collecting tensorflow-text~=2.8.0
#   Downloading tensorflow_text-2.8.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 82.3 MB/s
# Collecting py-cpuinfo>=3.3.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 14.2 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.8 MB/s
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 19.6 MB/s
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.2-py2.py3-none-any.whl (237 kB)
#      |████████████████████████████████| 237 kB 96.4 MB/s
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 96.3 MB/s
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.21.6)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.8 MB)
#      |████████████████████████████████| 47.8 MB 1.2 MB/s
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 67.6 MB/s
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 14.2 MB/s
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.12.11)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.17.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.35.0)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.31.5)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.17.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (21.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2022.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.23.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.8)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2021.10.8)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.4)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (0.25.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (4.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 58.8 MB/s
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.44.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (0.5.3)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (14.0.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (2.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.7)
# Collecting orjson<4.0
#   Downloading orjson-3.6.8-cp37-cp37m-manylinux_2_24_x86_64.whl (253 kB)
#      |████████████████████████████████| 253 kB 77.3 MB/s
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.4.11-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 75.5 MB/s
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.12.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (508 kB)
#      |████████████████████████████████| 508 kB 70.0 MB/s
# Requirement already satisfied: pyarrow<7.0.0,>=0.15.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (6.0.1)
# Collecting proto-plus<2,>=1.7.1
#   Downloading proto_plus-1.20.3-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 4.7 MB/s
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 105.0 MB/s
# Collecting cloudpickle<3,>=2.0.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting requests<3.0.0dev,>=2.18.0
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.5 MB/s
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.20.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 71.2 MB/s
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.0.12)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (4.1.2.30)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (1.4.2)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (0.8.9)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (2019.12.20)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (21.4.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.16.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.7.1)
# Building wheels for collected packages: object-detection, py-cpuinfo, dill, avro-python3, seqeval
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1692736 sha256=6a94e3889d283ef656caf367e5bcdb2fe61ded7bb6cd24bb20ab0461a0f21bc0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jbljy40g/wheels/e9/a3/68/8a5ce16756e32afc910584fa2e9084fc4bb393bdee370bf536
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22257 sha256=d02f958a50d3196a076a1da43b0b832fe3395e35c960c7a5ef7b5b9744389a00
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78544 sha256=2ccfd97ef8569a309927a0a6c6eb54ea28a03c79673afcfa6828736965a82bbe
#   Stored in directory: /root/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=44010 sha256=04bfeffbab2e01b485a5dcd01e3c8c827806543a2b7c099c28ea8a86347e7731
#   Stored in directory: /root/.cache/pip/wheels/d6/e5/b1/6b151d9b535ee50aaa6ab27d145a0104b6df02e5636f0376da
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=3efa55de283f6329ca10fb7342d55aaa6ee21f1b0da2cc7c056aca05647b77fb
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built object-detection py-cpuinfo dill avro-python3 seqeval
# Installing collected packages: requests, protobuf, tf-estimator-nightly, portalocker, dill, colorama, tf-slim, tensorflow-text, tensorflow-model-optimization, tensorflow-addons, seqeval, sentencepiece, sacrebleu, pyyaml, pymongo, py-cpuinfo, proto-plus, orjson, opencv-python-headless, hdfs, fastavro, cloudpickle, tf-models-official, tensorflow-io, lvis, avro-python3, apache-beam, object-detection
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.4
#     Uninstalling dill-0.3.4:
#       Successfully uninstalled dill-0.3.4
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.1.1
#     Uninstalling pymongo-4.1.1:
#       Successfully uninstalled pymongo-4.1.1
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# multiprocess 0.70.12.2 requires dill>=0.3.4, but you have dill 0.3.1.1 which is incompatible.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.0.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed apache-beam-2.38.0 avro-python3-1.10.2 cloudpickle-2.0.0 colorama-0.4.4 dill-0.3.1.1 fastavro-1.4.11 hdfs-2.7.0 lvis-0.5.3 object-detection-0.1 opencv-python-headless-4.5.5.64 orjson-3.6.8 portalocker-2.4.0 proto-plus-1.20.3 protobuf-3.20.1 py-cpuinfo-8.0.0 pymongo-3.12.3 pyyaml-5.4.1 requests-2.27.1 sacrebleu-2.0.0 sentencepiece-0.1.96 seqeval-1.2.2 tensorflow-addons-0.16.1 tensorflow-io-0.25.0 tensorflow-model-optimization-0.7.2 tensorflow-text-2.8.2 tf-estimator-nightly-2.8.0.dev2021122109 tf-models-official-2.8.0 tf-slim-1.1.0

# %%
# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk
# !pip install -q pycocotools
# Out:
# Selecting previously unselected package python-bs4.
# (Reading database ... 155203 files and directories currently installed.)
# Preparing to unpack .../0-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../1-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../2-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../4-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# Preparing to unpack .../5-python-html5lib_0.999999999-1_all.deb ...
# Unpacking python-html5lib (0.999999999-1) ...
# Selecting previously unselected package python-lxml:amd64.
# Preparing to unpack .../6-python-lxml_4.2.1-1ubuntu0.6_amd64.deb ...
# Unpacking python-lxml:amd64 (4.2.1-1ubuntu0.6) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../7-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../8-python-pil_5.1.0-1ubuntu0.7_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1ubuntu0.7) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-bs4 (4.6.0-1) ...
# Setting up python-lxml:amd64 (4.2.1-1ubuntu0.6) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up python-pil:amd64 (5.1.0-1ubuntu0.7) ...
# Setting up python-webencodings (0.5-2) ...
# Setting up python-chardet (3.0.4-1) ...
# Setting up python-html5lib (0.999999999-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
libs_path = '/content/gdrive/MyDrive/Colab\ Notebooks/lib'
# !pip3 uninstall opencv-python-headless==4.5.5.62
# !pip3 install --target=$libs_path opencv-python-headless==4.5.2.52
# Out:
# Found existing installation: opencv-python-headless 4.5.5.64
# Uninstalling opencv-python-headless-4.5.5.64:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/cv2/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless-4.5.5.64.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavcodec-65fa80df.so.58.134.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavformat-8ef5c7db.so.58.76.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavutil-9c768859.so.56.70.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libbz2-a273e504.so.1.0.6
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libcrypto-09fe7800.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libgfortran-91cc3cb1.so.3.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libopenblas-r0-f650aae0.3.3.so
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libssl-b92f8066.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libswresample-99364a1c.so.3.9.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libswscale-e6451464.so.5.9.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libvpx-1016051d.so.7.0.0
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libQtCore-bbdab771.so.4.8.7
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libQtGui-903938cd.so.4.8.7
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libQtTest-1183da5d.so.4.8.7
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libavcodec-3cdd3bd4.so.58.62.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libavformat-69a63b50.so.58.35.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libavutil-8e8979a8.so.56.36.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libbz2-7225278b.so.1.0.3
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libcrypto-a25ff511.so.1.1
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libssl-fdf0b66c.so.1.1
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libswresample-c6b3bbb9.so.3.6.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libswscale-2d19f7d1.so.5.6.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libvpx-c887ea55.so.6.1.0
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libz-a147dcb0.so.1.2.3
#     /usr/local/lib/python3.7/dist-packages/cv2/cv2.cpython-37m-x86_64-linux-gnu.so
# Proceed (y/n)? y
#   Successfully uninstalled opencv-python-headless-4.5.5.64
# Collecting opencv-python-headless==4.5.2.52
#   Downloading opencv_python_headless-4.5.2.52-cp37-cp37m-manylinux2014_x86_64.whl (38.2 MB)
#      |████████████████████████████████| 38.2 MB 92.1 MB/s
# Collecting numpy>=1.14.5
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 59.0 MB/s
# Installing collected packages: numpy, opencv-python-headless
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.0.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.21.6 opencv-python-headless-4.5.2.52
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/numpy-1.21.6.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/opencv_python_headless.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/cv2 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/numpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/opencv_python_headless-4.5.2.52.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/numpy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/gdrive/MyDrive/Colab Notebooks/lib/bin already exists. Specify --upgrade to force replacement.

# %% [markdown]
# ##Navigate to project folder - set my current paths

# %%
path = '/content/gdrive/MyDrive/GoogleColab'
udacity_path = path + '/UDACITY'
sdc_path = udacity_path + '/SDC'
project_path = sdc_path + '/1-waymo-object-detection'


#Google drive
data_path = project_path + '/data'
waymo_path = data_path + '/waymo'
train_dir = data_path + '/train/'
val_dir = data_path + '/val/'
test_dir = data_path + '/test'
experiments_data = data_path + '/experiments_data'
model_ckpts = experiments_data + '/pretrained_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0'
tfrecord_test = test_dir + 'segment-12200383401366682847_2552_140_2572_140_with_camera_labels.tfrecord'

current_dir = experiments_data + '/experiment2'
pipeline_config_path = current_dir + '/pipeline_new.config'
exported_dir = current_dir + '/exported'
saved_model_dir = exported_dir + '/saved_model'
animation_path = current_dir + '/animation.mp4'

#Github clone
folder_path = project_path + '/Udacity-waymo-object-detection'
workspace_path = folder_path + '/home/workspace'
experiments_path = workspace_path + 'experiments/'
label_map = workspace_path + 'experiments/label_map.pbtxt'

# %%
import tensorflow as tf
print(tf.__version__)

# %%
#test if the imports are correct
# %cd $workspace_path
# !git pull
# !python utils_colab.py

# %% [markdown]
# ##Create pipeline_new.config (do it once)

# %%
'''
#create pipeline_new.config 
# %cd $workspace_path
# !python edit_config.py --train_dir $train_dir --eval_dir $val_dir --batch_size 2 --checkpoint $model_ckpts --label_map $label_map
'''

# %% [markdown]
# ##Set GPU utils

# %%
print("TF GPU: ",tf.test.gpu_device_name())
# !nvcc --version
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0,2,3,4
# Out:
# TF GPU:  /device:GPU:0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0,2,3,4

# %%
# %env CUDA_VISIBLE_DEVICES
# Out:
# '0,2,3,4'

# %%
# %env CUDA_DEVICE_ORDER
# Out:
# 'PCI_BUS_ID'

# %%
# !nvidia-smi
# Out:
# Mon May  9 13:24:27 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    25W /  70W |    264MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ##Start Tensorboard
#
# see https://medium.com/swlh/tensorflow-2-object-detection-api-with-google-colab-b2af171e81cc

# %%
#start Tensorboard
# %load_ext tensorboard
# %tensorboard --logdir=$current_dir

# %% [markdown]
# ![](https://drive.google.com/uc?id=1hqkG-tDxHuqLZ3GP8SeetRb09OVKrPQI)
# ![](https://drive.google.com/uc?id=10GruBcPZoX2TWDpfGkiKx_4lubJJMkQK)

# %% [markdown]
# ##Paths:
#
# ```
# path = '/content/gdrive/MyDrive/GoogleColab'
# udacity_path = path + '/UDACITY'
# sdc_path = udacity_path + '/SDC'
# project_path = sdc_path + '/1-waymo-object-detection'
#
#
# #Google drive
# data_path = project_path + '/data'
# waymo_path = data_path + '/waymo'
# train_dir = data_path + '/train/'
# val_dir = data_path + '/val/'
# test_dir = data_path + '/test'
# experiments_data = data_path + '/experiments_data'
# model_ckpts = experiments_data + '/pretrained_model/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0'
# tfrecord_test = test_dir + 'segment-12200383401366682847_2552_140_2572_140_with_camera_labels.tfrecord'
#
# current_dir = experiments_data + '/experiment2'
# pipeline_config_path = current_dir + '/pipeline_new.config'
# exported_dir = current_dir + '/exported'
# saved_model_dir = exported_dir + '/saved_model'
# animation_path = current_dir + '/animation.mp4'
#
# #Github clone
# folder_path = project_path + '/Udacity-waymo-object-detection'
# workspace_path = folder_path + '/home/workspace'
# experiments_path = workspace_path + 'experiments/'
# label_map = workspace_path + 'experiments/label_map.pbtxt'
# ```

# %%
# %cd workspace_path

# %% [markdown]
# ## Train model

# %%
# !python model_main_tf2.py --model_dir=$current_dir --pipeline_config_path=$pipeline_config_path
# Out:
# 2022-05-09 13:24:44.484438: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0509 13:24:44.510606 140465385244544 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0509 13:24:44.517706 140465385244544 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0509 13:24:44.517886 140465385244544 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0509 13:24:44.656075 140465385244544 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10153695247769592104_787_000_807_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10023947602400723454_1120_000_1140_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10072140764565668044_4060_000_4080_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10107710434105775874_760_000_780_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10096619443888687526_2820_000_2840_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10017090168044687777_6380_000_6400_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10082223140073588526_6140_000_6160_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10061305430875486848_1080_000_1100_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1022527355599519580_4866_960_4886_960_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10226164909075980558_180_000_200_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10231929575853664160_1160_000_1180_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10206293520369375008_2796_800_2816_800_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10235335145367115211_5420_000_5440_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10275144660749673822_5755_561_5775_561_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10444454289801298640_4360_000_4380_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10455472356147194054_1560_000_1580_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10212406498497081993_5300_000_5320_000_with_camera_labels.tfrecord', '/content/gdrive/MyD ...
# I0509 13:24:44.670424 140465385244544 dataset_builder.py:162] Reading unweighted datasets: ['/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10153695247769592104_787_000_807_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10023947602400723454_1120_000_1140_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10072140764565668044_4060_000_4080_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10107710434105775874_760_000_780_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10096619443888687526_2820_000_2840_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10017090168044687777_6380_000_6400_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10082223140073588526_6140_000_6160_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10061305430875486848_1080_000_1100_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1022527355599519580_4866_960_4886_960_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10226164909075980558_180_000_200_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10231929575853664160_1160_000_1180_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10206293520369375008_2796_800_2816_800_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10235335145367115211_5420_000_5440_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10275144660749673822_5755_561_5775_561_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10444454289801298640_4360_000_4380_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10455472356147194054_1560_000_1580_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10212406498497081993_5300_000_5320_000_with ...
# INFO:tensorflow:Reading record datasets for input file: ['/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10153695247769592104_787_000_807_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10023947602400723454_1120_000_1140_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10072140764565668044_4060_000_4080_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10107710434105775874_760_000_780_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10096619443888687526_2820_000_2840_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10017090168044687777_6380_000_6400_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10082223140073588526_6140_000_6160_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10061305430875486848_1080_000_1100_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1022527355599519580_4866_960_4886_960_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10226164909075980558_180_000_200_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10231929575853664160_1160_000_1180_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10206293520369375008_2796_800_2816_800_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10235335145367115211_5420_000_5440_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10275144660749673822_5755_561_5775_561_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10444454289801298640_4360_000_4380_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10455472356147194054_1560_000_1580_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10212406498497081993_5300_000_5320_000_with_camera_labels.tfrecord', '/content ...
# I0509 13:24:46.152666 140465385244544 dataset_builder.py:79] Reading record datasets for input file: ['/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10153695247769592104_787_000_807_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10023947602400723454_1120_000_1140_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10072140764565668044_4060_000_4080_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10107710434105775874_760_000_780_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10096619443888687526_2820_000_2840_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10017090168044687777_6380_000_6400_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10082223140073588526_6140_000_6160_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10061305430875486848_1080_000_1100_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-1022527355599519580_4866_960_4886_960_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10226164909075980558_180_000_200_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10231929575853664160_1160_000_1180_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10206293520369375008_2796_800_2816_800_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10235335145367115211_5420_000_5440_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10275144660749673822_5755_561_5775_561_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10444454289801298640_4360_000_4380_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10455472356147194054_1560_000_1580_000_with_camera_labels.tfrecord', '/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/train/segment-10212406498497081993_5300_000_532 ...
# INFO:tensorflow:Number of filenames to read: 82
# I0509 13:24:46.229001 140465385244544 dataset_builder.py:80] Number of filenames to read: 82
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0509 13:24:46.235085 140465385244544 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0509 13:24:46.269719 140465385244544 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0509 13:24:52.563165 140465385244544 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0509 13:24:55.691770 140465385244544 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# W0509 13:24:58.152505 140465385244544 deprecation.py:547] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0509 13:24:59.711195 140465385244544 deprecation.py:343] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0509 13:25:42.949732 140465385244544 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0509 13:25:42.950895 140465385244544 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0509 13:25:42.952722 140465385244544 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0509 13:25:42.953555 140465385244544 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0509 13:25:42.955404 140465385244544 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0509 13:25:42.956216 140465385244544 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0509 13:25:42.958336 140465385244544 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0509 13:25:42.959160 140465385244544 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0509 13:25:42.960599 140465385244544 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0509 13:25:42.961404 140465385244544 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0509 13:25:44.660864 140460205950720 deprecation.py:547] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.927s
# I0509 13:27:17.250396 140465385244544 model_lib_v2.py:707] Step 100 per-step time 0.927s
# INFO:tensorflow:{'Loss/classification_loss': 0.6989505,
#  'Loss/localization_loss': 0.5773783,
#  'Loss/regularization_loss': 0.24862798,
#  'Loss/total_loss': 1.5249568,
#  'learning_rate': 0.0041596}
# I0509 13:27:17.250763 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.6989505,
#  'Loss/localization_loss': 0.5773783,
#  'Loss/regularization_loss': 0.24862798,
#  'Loss/total_loss': 1.5249568,
#  'learning_rate': 0.0041596}
# INFO:tensorflow:Step 200 per-step time 0.598s
# I0509 13:28:16.830293 140465385244544 model_lib_v2.py:707] Step 200 per-step time 0.598s
# INFO:tensorflow:{'Loss/classification_loss': 0.67982715,
#  'Loss/localization_loss': 0.5991252,
#  'Loss/regularization_loss': 0.25365028,
#  'Loss/total_loss': 1.5326027,
#  'learning_rate': 0.0073192}
# I0509 13:28:16.830659 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.67982715,
#  'Loss/localization_loss': 0.5991252,
#  'Loss/regularization_loss': 0.25365028,
#  'Loss/total_loss': 1.5326027,
#  'learning_rate': 0.0073192}
# INFO:tensorflow:Step 300 per-step time 0.597s
# I0509 13:29:16.550343 140465385244544 model_lib_v2.py:707] Step 300 per-step time 0.597s
# INFO:tensorflow:{'Loss/classification_loss': 1.0856555,
#  'Loss/localization_loss': 0.5471376,
#  'Loss/regularization_loss': 0.35759062,
#  'Loss/total_loss': 1.9903836,
#  'learning_rate': 0.0104788}
# I0509 13:29:16.550677 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 1.0856555,
#  'Loss/localization_loss': 0.5471376,
#  'Loss/regularization_loss': 0.35759062,
#  'Loss/total_loss': 1.9903836,
#  'learning_rate': 0.0104788}
# INFO:tensorflow:Step 400 per-step time 0.596s
# I0509 13:30:16.162495 140465385244544 model_lib_v2.py:707] Step 400 per-step time 0.596s
# INFO:tensorflow:{'Loss/classification_loss': 0.94318885,
#  'Loss/localization_loss': 0.69550985,
#  'Loss/regularization_loss': 0.43619725,
#  'Loss/total_loss': 2.0748959,
#  'learning_rate': 0.0136384}
# I0509 13:30:16.162818 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.94318885,
#  'Loss/localization_loss': 0.69550985,
#  'Loss/regularization_loss': 0.43619725,
#  'Loss/total_loss': 2.0748959,
#  'learning_rate': 0.0136384}
# INFO:tensorflow:Step 500 per-step time 0.593s
# I0509 13:31:15.440909 140465385244544 model_lib_v2.py:707] Step 500 per-step time 0.593s
# INFO:tensorflow:{'Loss/classification_loss': 10.696215,
#  'Loss/localization_loss': 0.7416301,
#  'Loss/regularization_loss': 1.1488014,
#  'Loss/total_loss': 12.586647,
#  'learning_rate': 0.016797999}
# I0509 13:31:15.441237 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 10.696215,
#  'Loss/localization_loss': 0.7416301,
#  'Loss/regularization_loss': 1.1488014,
#  'Loss/total_loss': 12.586647,
#  'learning_rate': 0.016797999}
# INFO:tensorflow:Step 600 per-step time 0.591s
# I0509 13:32:14.499063 140465385244544 model_lib_v2.py:707] Step 600 per-step time 0.591s
# INFO:tensorflow:{'Loss/classification_loss': 2.8688939,
#  'Loss/localization_loss': 0.8304979,
#  'Loss/regularization_loss': 1.9766811,
#  'Loss/total_loss': 5.676073,
#  'learning_rate': 0.0199576}
# I0509 13:32:14.499399 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 2.8688939,
#  'Loss/localization_loss': 0.8304979,
#  'Loss/regularization_loss': 1.9766811,
#  'Loss/total_loss': 5.676073,
#  'learning_rate': 0.0199576}
# INFO:tensorflow:Step 700 per-step time 0.590s
# I0509 13:33:13.465891 140465385244544 model_lib_v2.py:707] Step 700 per-step time 0.590s
# INFO:tensorflow:{'Loss/classification_loss': 2.3372796,
#  'Loss/localization_loss': 0.7992748,
#  'Loss/regularization_loss': 3.9975016,
#  'Loss/total_loss': 7.134056,
#  'learning_rate': 0.0231172}
# I0509 13:33:13.466207 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 2.3372796,
#  'Loss/localization_loss': 0.7992748,
#  'Loss/regularization_loss': 3.9975016,
#  'Loss/total_loss': 7.134056,
#  'learning_rate': 0.0231172}
# INFO:tensorflow:Step 800 per-step time 0.586s
# I0509 13:34:12.113361 140465385244544 model_lib_v2.py:707] Step 800 per-step time 0.586s
# INFO:tensorflow:{'Loss/classification_loss': 1.3572565,
#  'Loss/localization_loss': 0.8525884,
#  'Loss/regularization_loss': 4.210145,
#  'Loss/total_loss': 6.41999,
#  'learning_rate': 0.026276799}
# I0509 13:34:12.113673 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 1.3572565,
#  'Loss/localization_loss': 0.8525884,
#  'Loss/regularization_loss': 4.210145,
#  'Loss/total_loss': 6.41999,
#  'learning_rate': 0.026276799}
# INFO:tensorflow:Step 900 per-step time 0.587s
# I0509 13:35:10.764561 140465385244544 model_lib_v2.py:707] Step 900 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.8616058,
#  'Loss/localization_loss': 0.7359983,
#  'Loss/regularization_loss': 4.173877,
#  'Loss/total_loss': 5.7714806,
#  'learning_rate': 0.029436398}
# I0509 13:35:10.764862 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.8616058,
#  'Loss/localization_loss': 0.7359983,
#  'Loss/regularization_loss': 4.173877,
#  'Loss/total_loss': 5.7714806,
#  'learning_rate': 0.029436398}
# INFO:tensorflow:Step 1000 per-step time 0.588s
# I0509 13:36:09.557424 140465385244544 model_lib_v2.py:707] Step 1000 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 0.8267866,
#  'Loss/localization_loss': 0.8157738,
#  'Loss/regularization_loss': 4.183123,
#  'Loss/total_loss': 5.8256836,
#  'learning_rate': 0.032595996}
# I0509 13:36:09.557703 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.8267866,
#  'Loss/localization_loss': 0.8157738,
#  'Loss/regularization_loss': 4.183123,
#  'Loss/total_loss': 5.8256836,
#  'learning_rate': 0.032595996}
# INFO:tensorflow:Step 1100 per-step time 0.586s
# I0509 13:37:08.202871 140465385244544 model_lib_v2.py:707] Step 1100 per-step time 0.586s
# INFO:tensorflow:{'Loss/classification_loss': 0.9063686,
#  'Loss/localization_loss': 0.709255,
#  'Loss/regularization_loss': 4.1318145,
#  'Loss/total_loss': 5.747438,
#  'learning_rate': 0.035755597}
# I0509 13:37:08.203166 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.9063686,
#  'Loss/localization_loss': 0.709255,
#  'Loss/regularization_loss': 4.1318145,
#  'Loss/total_loss': 5.747438,
#  'learning_rate': 0.035755597}
# INFO:tensorflow:Step 1200 per-step time 0.587s
# I0509 13:38:06.875859 140465385244544 model_lib_v2.py:707] Step 1200 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.82128394,
#  'Loss/localization_loss': 0.9349121,
#  'Loss/regularization_loss': 4.0508733,
#  'Loss/total_loss': 5.8070693,
#  'learning_rate': 0.0389152}
# I0509 13:38:06.876147 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.82128394,
#  'Loss/localization_loss': 0.9349121,
#  'Loss/regularization_loss': 4.0508733,
#  'Loss/total_loss': 5.8070693,
#  'learning_rate': 0.0389152}
# INFO:tensorflow:Step 1300 per-step time 0.588s
# I0509 13:39:05.685574 140465385244544 model_lib_v2.py:707] Step 1300 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 0.82748985,
#  'Loss/localization_loss': 0.7757392,
#  'Loss/regularization_loss': 3.9531336,
#  'Loss/total_loss': 5.5563626,
#  'learning_rate': 0.042074796}
# I0509 13:39:05.685847 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.82748985,
#  'Loss/localization_loss': 0.7757392,
#  'Loss/regularization_loss': 3.9531336,
#  'Loss/total_loss': 5.5563626,
#  'learning_rate': 0.042074796}
# INFO:tensorflow:Step 1400 per-step time 0.586s
# I0509 13:40:04.287681 140465385244544 model_lib_v2.py:707] Step 1400 per-step time 0.586s
# INFO:tensorflow:{'Loss/classification_loss': 0.7694249,
#  'Loss/localization_loss': 0.73427844,
#  'Loss/regularization_loss': 3.8241956,
#  'Loss/total_loss': 5.327899,
#  'learning_rate': 0.045234397}
# I0509 13:40:04.287981 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.7694249,
#  'Loss/localization_loss': 0.73427844,
#  'Loss/regularization_loss': 3.8241956,
#  'Loss/total_loss': 5.327899,
#  'learning_rate': 0.045234397}
# INFO:tensorflow:Step 1500 per-step time 0.588s
# I0509 13:41:03.056666 140465385244544 model_lib_v2.py:707] Step 1500 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 0.7433263,
#  'Loss/localization_loss': 0.6659913,
#  'Loss/regularization_loss': 3.6900191,
#  'Loss/total_loss': 5.0993366,
#  'learning_rate': 0.048393995}
# I0509 13:41:03.056992 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.7433263,
#  'Loss/localization_loss': 0.6659913,
#  'Loss/regularization_loss': 3.6900191,
#  'Loss/total_loss': 5.0993366,
#  'learning_rate': 0.048393995}
# INFO:tensorflow:Step 1600 per-step time 0.587s
# I0509 13:42:01.729766 140465385244544 model_lib_v2.py:707] Step 1600 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.83898526,
#  'Loss/localization_loss': 0.9491189,
#  'Loss/regularization_loss': 3.5489476,
#  'Loss/total_loss': 5.337052,
#  'learning_rate': 0.051553596}
# I0509 13:42:01.730039 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.83898526,
#  'Loss/localization_loss': 0.9491189,
#  'Loss/regularization_loss': 3.5489476,
#  'Loss/total_loss': 5.337052,
#  'learning_rate': 0.051553596}
# INFO:tensorflow:Step 1700 per-step time 0.587s
# I0509 13:43:00.404706 140465385244544 model_lib_v2.py:707] Step 1700 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.6361045,
#  'Loss/localization_loss': 0.7816167,
#  'Loss/regularization_loss': 3.4093506,
#  'Loss/total_loss': 4.827072,
#  'learning_rate': 0.054713197}
# I0509 13:43:00.405021 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.6361045,
#  'Loss/localization_loss': 0.7816167,
#  'Loss/regularization_loss': 3.4093506,
#  'Loss/total_loss': 4.827072,
#  'learning_rate': 0.054713197}
# INFO:tensorflow:Step 1800 per-step time 0.587s
# I0509 13:43:59.120273 140465385244544 model_lib_v2.py:707] Step 1800 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.8411441,
#  'Loss/localization_loss': 0.85696757,
#  'Loss/regularization_loss': 3.2630482,
#  'Loss/total_loss': 4.9611597,
#  'learning_rate': 0.057872795}
# I0509 13:43:59.120531 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.8411441,
#  'Loss/localization_loss': 0.85696757,
#  'Loss/regularization_loss': 3.2630482,
#  'Loss/total_loss': 4.9611597,
#  'learning_rate': 0.057872795}
# INFO:tensorflow:Step 1900 per-step time 0.588s
# I0509 13:44:57.914791 140465385244544 model_lib_v2.py:707] Step 1900 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 1.2018447,
#  'Loss/localization_loss': 0.8135062,
#  'Loss/regularization_loss': 3.116099,
#  'Loss/total_loss': 5.1314497,
#  'learning_rate': 0.061032396}
# I0509 13:44:57.915098 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 1.2018447,
#  'Loss/localization_loss': 0.8135062,
#  'Loss/regularization_loss': 3.116099,
#  'Loss/total_loss': 5.1314497,
#  'learning_rate': 0.061032396}
# INFO:tensorflow:Step 2000 per-step time 0.588s
# I0509 13:45:56.666974 140465385244544 model_lib_v2.py:707] Step 2000 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 0.6732247,
#  'Loss/localization_loss': 0.6432557,
#  'Loss/regularization_loss': 2.9951286,
#  'Loss/total_loss': 4.3116093,
#  'learning_rate': 0.064192}
# I0509 13:45:56.667258 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.6732247,
#  'Loss/localization_loss': 0.6432557,
#  'Loss/regularization_loss': 2.9951286,
#  'Loss/total_loss': 4.3116093,
#  'learning_rate': 0.064192}
# INFO:tensorflow:Step 2100 per-step time 0.602s
# I0509 13:46:56.885565 140465385244544 model_lib_v2.py:707] Step 2100 per-step time 0.602s
# INFO:tensorflow:{'Loss/classification_loss': 0.78045326,
#  'Loss/localization_loss': 0.90303785,
#  'Loss/regularization_loss': 2.857851,
#  'Loss/total_loss': 4.5413423,
#  'learning_rate': 0.0673516}
# I0509 13:46:56.885858 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.78045326,
#  'Loss/localization_loss': 0.90303785,
#  'Loss/regularization_loss': 2.857851,
#  'Loss/total_loss': 4.5413423,
#  'learning_rate': 0.0673516}
# INFO:tensorflow:Step 2200 per-step time 0.587s
# I0509 13:47:55.626770 140465385244544 model_lib_v2.py:707] Step 2200 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.85028946,
#  'Loss/localization_loss': 0.7220549,
#  'Loss/regularization_loss': 2.7135582,
#  'Loss/total_loss': 4.2859025,
#  'learning_rate': 0.0705112}
# I0509 13:47:55.627050 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.85028946,
#  'Loss/localization_loss': 0.7220549,
#  'Loss/regularization_loss': 2.7135582,
#  'Loss/total_loss': 4.2859025,
#  'learning_rate': 0.0705112}
# INFO:tensorflow:Step 2300 per-step time 0.587s
# I0509 13:48:54.330081 140465385244544 model_lib_v2.py:707] Step 2300 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.6318907,
#  'Loss/localization_loss': 0.6510699,
#  'Loss/regularization_loss': 2.564257,
#  'Loss/total_loss': 3.8472176,
#  'learning_rate': 0.0736708}
# I0509 13:48:54.330381 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.6318907,
#  'Loss/localization_loss': 0.6510699,
#  'Loss/regularization_loss': 2.564257,
#  'Loss/total_loss': 3.8472176,
#  'learning_rate': 0.0736708}
# INFO:tensorflow:Step 2400 per-step time 0.589s
# I0509 13:49:53.232923 140465385244544 model_lib_v2.py:707] Step 2400 per-step time 0.589s
# INFO:tensorflow:{'Loss/classification_loss': 0.8301074,
#  'Loss/localization_loss': 0.8817332,
#  'Loss/regularization_loss': 2.4186187,
#  'Loss/total_loss': 4.1304593,
#  'learning_rate': 0.0768304}
# I0509 13:49:53.233187 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.8301074,
#  'Loss/localization_loss': 0.8817332,
#  'Loss/regularization_loss': 2.4186187,
#  'Loss/total_loss': 4.1304593,
#  'learning_rate': 0.0768304}
# INFO:tensorflow:Step 2500 per-step time 0.586s
# I0509 13:50:51.878296 140465385244544 model_lib_v2.py:707] Step 2500 per-step time 0.586s
# INFO:tensorflow:{'Loss/classification_loss': 0.63460284,
#  'Loss/localization_loss': 0.7248189,
#  'Loss/regularization_loss': 2.28308,
#  'Loss/total_loss': 3.6425018,
#  'learning_rate': 0.07999}
# I0509 13:50:51.878575 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.63460284,
#  'Loss/localization_loss': 0.7248189,
#  'Loss/regularization_loss': 2.28308,
#  'Loss/total_loss': 3.6425018,
#  'learning_rate': 0.07999}
# INFO:tensorflow:Step 2600 per-step time 0.588s
# I0509 13:51:50.661908 140465385244544 model_lib_v2.py:707] Step 2600 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 0.7318613,
#  'Loss/localization_loss': 0.70950645,
#  'Loss/regularization_loss': 2.1519675,
#  'Loss/total_loss': 3.5933352,
#  'learning_rate': 0.079987384}
# I0509 13:51:50.662167 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.7318613,
#  'Loss/localization_loss': 0.70950645,
#  'Loss/regularization_loss': 2.1519675,
#  'Loss/total_loss': 3.5933352,
#  'learning_rate': 0.079987384}
# INFO:tensorflow:Step 2700 per-step time 0.587s
# I0509 13:52:49.374701 140465385244544 model_lib_v2.py:707] Step 2700 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.80202746,
#  'Loss/localization_loss': 0.7795705,
#  'Loss/regularization_loss': 2.043755,
#  'Loss/total_loss': 3.625353,
#  'learning_rate': 0.07997956}
# I0509 13:52:49.374989 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.80202746,
#  'Loss/localization_loss': 0.7795705,
#  'Loss/regularization_loss': 2.043755,
#  'Loss/total_loss': 3.625353,
#  'learning_rate': 0.07997956}
# INFO:tensorflow:Step 2800 per-step time 0.588s
# I0509 13:53:48.146648 140465385244544 model_lib_v2.py:707] Step 2800 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 0.7522071,
#  'Loss/localization_loss': 0.7568396,
#  'Loss/regularization_loss': 1.9209913,
#  'Loss/total_loss': 3.430038,
#  'learning_rate': 0.079966515}
# I0509 13:53:48.146907 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.7522071,
#  'Loss/localization_loss': 0.7568396,
#  'Loss/regularization_loss': 1.9209913,
#  'Loss/total_loss': 3.430038,
#  'learning_rate': 0.079966515}
# INFO:tensorflow:Step 2900 per-step time 0.586s
# I0509 13:54:46.774141 140465385244544 model_lib_v2.py:707] Step 2900 per-step time 0.586s
# INFO:tensorflow:{'Loss/classification_loss': 0.68019414,
#  'Loss/localization_loss': 0.7253046,
#  'Loss/regularization_loss': 1.8114256,
#  'Loss/total_loss': 3.2169242,
#  'learning_rate': 0.079948254}
# I0509 13:54:46.774426 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.68019414,
#  'Loss/localization_loss': 0.7253046,
#  'Loss/regularization_loss': 1.8114256,
#  'Loss/total_loss': 3.2169242,
#  'learning_rate': 0.079948254}
# INFO:tensorflow:Step 3000 per-step time 0.587s
# I0509 13:55:45.429735 140465385244544 model_lib_v2.py:707] Step 3000 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.6882336,
#  'Loss/localization_loss': 0.8972113,
#  'Loss/regularization_loss': 1.7049471,
#  'Loss/total_loss': 3.290392,
#  'learning_rate': 0.07992477}
# I0509 13:55:45.430019 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.6882336,
#  'Loss/localization_loss': 0.8972113,
#  'Loss/regularization_loss': 1.7049471,
#  'Loss/total_loss': 3.290392,
#  'learning_rate': 0.07992477}
# INFO:tensorflow:Step 3100 per-step time 0.588s
# I0509 13:56:44.264053 140465385244544 model_lib_v2.py:707] Step 3100 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 0.71436304,
#  'Loss/localization_loss': 0.6704954,
#  'Loss/regularization_loss': 1.6050988,
#  'Loss/total_loss': 2.9899573,
#  'learning_rate': 0.079896085}
# I0509 13:56:44.264331 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.71436304,
#  'Loss/localization_loss': 0.6704954,
#  'Loss/regularization_loss': 1.6050988,
#  'Loss/total_loss': 2.9899573,
#  'learning_rate': 0.079896085}
# INFO:tensorflow:Step 3200 per-step time 0.587s
# I0509 13:57:43.011893 140465385244544 model_lib_v2.py:707] Step 3200 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.8131673,
#  'Loss/localization_loss': 0.7613499,
#  'Loss/regularization_loss': 1.5115844,
#  'Loss/total_loss': 3.0861015,
#  'learning_rate': 0.079862185}
# I0509 13:57:43.012166 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.8131673,
#  'Loss/localization_loss': 0.7613499,
#  'Loss/regularization_loss': 1.5115844,
#  'Loss/total_loss': 3.0861015,
#  'learning_rate': 0.079862185}
# INFO:tensorflow:Step 3300 per-step time 0.587s
# I0509 13:58:41.719660 140465385244544 model_lib_v2.py:707] Step 3300 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.66829485,
#  'Loss/localization_loss': 0.599614,
#  'Loss/regularization_loss': 1.4276261,
#  'Loss/total_loss': 2.695535,
#  'learning_rate': 0.07982309}
# I0509 13:58:41.719959 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.66829485,
#  'Loss/localization_loss': 0.599614,
#  'Loss/regularization_loss': 1.4276261,
#  'Loss/total_loss': 2.695535,
#  'learning_rate': 0.07982309}
# INFO:tensorflow:Step 3400 per-step time 0.587s
# I0509 13:59:40.394963 140465385244544 model_lib_v2.py:707] Step 3400 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.77426744,
#  'Loss/localization_loss': 0.7208163,
#  'Loss/regularization_loss': 1.3507797,
#  'Loss/total_loss': 2.8458633,
#  'learning_rate': 0.07977879}
# I0509 13:59:40.395244 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.77426744,
#  'Loss/localization_loss': 0.7208163,
#  'Loss/regularization_loss': 1.3507797,
#  'Loss/total_loss': 2.8458633,
#  'learning_rate': 0.07977879}
# INFO:tensorflow:Step 3500 per-step time 0.587s
# I0509 14:00:39.128217 140465385244544 model_lib_v2.py:707] Step 3500 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.66237503,
#  'Loss/localization_loss': 0.74370104,
#  'Loss/regularization_loss': 1.2722472,
#  'Loss/total_loss': 2.6783233,
#  'learning_rate': 0.0797293}
# I0509 14:00:39.128521 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.66237503,
#  'Loss/localization_loss': 0.74370104,
#  'Loss/regularization_loss': 1.2722472,
#  'Loss/total_loss': 2.6783233,
#  'learning_rate': 0.0797293}
# INFO:tensorflow:Step 3600 per-step time 0.588s
# I0509 14:01:37.905727 140465385244544 model_lib_v2.py:707] Step 3600 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 1.0187546,
#  'Loss/localization_loss': 1.6854978,
#  'Loss/regularization_loss': 1.6097385,
#  'Loss/total_loss': 4.3139906,
#  'learning_rate': 0.07967463}
# I0509 14:01:37.906031 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 1.0187546,
#  'Loss/localization_loss': 1.6854978,
#  'Loss/regularization_loss': 1.6097385,
#  'Loss/total_loss': 4.3139906,
#  'learning_rate': 0.07967463}
# INFO:tensorflow:Step 3700 per-step time 0.589s
# I0509 14:02:36.830791 140465385244544 model_lib_v2.py:707] Step 3700 per-step time 0.589s
# INFO:tensorflow:{'Loss/classification_loss': 0.7162319,
#  'Loss/localization_loss': 0.71826935,
#  'Loss/regularization_loss': 2.145581,
#  'Loss/total_loss': 3.5800822,
#  'learning_rate': 0.07961477}
# I0509 14:02:36.831078 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.7162319,
#  'Loss/localization_loss': 0.71826935,
#  'Loss/regularization_loss': 2.145581,
#  'Loss/total_loss': 3.5800822,
#  'learning_rate': 0.07961477}
# INFO:tensorflow:Step 3800 per-step time 0.588s
# I0509 14:03:35.666452 140465385244544 model_lib_v2.py:707] Step 3800 per-step time 0.588s
# INFO:tensorflow:{'Loss/classification_loss': 0.65479654,
#  'Loss/localization_loss': 0.72673976,
#  'Loss/regularization_loss': 2.0170715,
#  'Loss/total_loss': 3.3986077,
#  'learning_rate': 0.07954975}
# I0509 14:03:35.666711 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.65479654,
#  'Loss/localization_loss': 0.72673976,
#  'Loss/regularization_loss': 2.0170715,
#  'Loss/total_loss': 3.3986077,
#  'learning_rate': 0.07954975}
# INFO:tensorflow:Step 3900 per-step time 0.589s
# I0509 14:04:34.551969 140465385244544 model_lib_v2.py:707] Step 3900 per-step time 0.589s
# INFO:tensorflow:{'Loss/classification_loss': 0.7271027,
#  'Loss/localization_loss': 0.6900987,
#  'Loss/regularization_loss': 1.8978716,
# ...
#  'Loss/total_loss': 1.1377842,
#  'learning_rate': 0.0018875194}
# I0509 17:55:48.690993 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.4699274,
#  'Loss/localization_loss': 0.5178678,
#  'Loss/regularization_loss': 0.14998901,
#  'Loss/total_loss': 1.1377842,
#  'learning_rate': 0.0018875194}
# INFO:tensorflow:Step 27400 per-step time 0.593s
# I0509 17:56:48.028985 140465385244544 model_lib_v2.py:707] Step 27400 per-step time 0.593s
# INFO:tensorflow:{'Loss/classification_loss': 0.34851083,
#  'Loss/localization_loss': 0.58977365,
#  'Loss/regularization_loss': 0.14978641,
#  'Loss/total_loss': 1.0880709,
#  'learning_rate': 0.0017513065}
# I0509 17:56:48.029274 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.34851083,
#  'Loss/localization_loss': 0.58977365,
#  'Loss/regularization_loss': 0.14978641,
#  'Loss/total_loss': 1.0880709,
#  'learning_rate': 0.0017513065}
# INFO:tensorflow:Step 27500 per-step time 0.594s
# I0509 17:57:47.390811 140465385244544 model_lib_v2.py:707] Step 27500 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.44440788,
#  'Loss/localization_loss': 0.40273237,
#  'Loss/regularization_loss': 0.14961517,
#  'Loss/total_loss': 0.9967554,
#  'learning_rate': 0.0016200758}
# I0509 17:57:47.391080 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.44440788,
#  'Loss/localization_loss': 0.40273237,
#  'Loss/regularization_loss': 0.14961517,
#  'Loss/total_loss': 0.9967554,
#  'learning_rate': 0.0016200758}
# INFO:tensorflow:Step 27600 per-step time 0.594s
# I0509 17:58:46.746577 140465385244544 model_lib_v2.py:707] Step 27600 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.3183802,
#  'Loss/localization_loss': 0.30819097,
#  'Loss/regularization_loss': 0.14944337,
#  'Loss/total_loss': 0.77601457,
#  'learning_rate': 0.0014938609}
# I0509 17:58:46.746882 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.3183802,
#  'Loss/localization_loss': 0.30819097,
#  'Loss/regularization_loss': 0.14944337,
#  'Loss/total_loss': 0.77601457,
#  'learning_rate': 0.0014938609}
# INFO:tensorflow:Step 27700 per-step time 0.594s
# I0509 17:59:46.098587 140465385244544 model_lib_v2.py:707] Step 27700 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.4383586,
#  'Loss/localization_loss': 0.4572175,
#  'Loss/regularization_loss': 0.14928754,
#  'Loss/total_loss': 1.0448637,
#  'learning_rate': 0.0013726664}
# I0509 17:59:46.098886 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.4383586,
#  'Loss/localization_loss': 0.4572175,
#  'Loss/regularization_loss': 0.14928754,
#  'Loss/total_loss': 1.0448637,
#  'learning_rate': 0.0013726664}
# INFO:tensorflow:Step 27800 per-step time 0.594s
# I0509 18:00:45.536570 140465385244544 model_lib_v2.py:707] Step 27800 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.29407844,
#  'Loss/localization_loss': 0.3280309,
#  'Loss/regularization_loss': 0.14914347,
#  'Loss/total_loss': 0.7712528,
#  'learning_rate': 0.0012565162}
# I0509 18:00:45.536846 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.29407844,
#  'Loss/localization_loss': 0.3280309,
#  'Loss/regularization_loss': 0.14914347,
#  'Loss/total_loss': 0.7712528,
#  'learning_rate': 0.0012565162}
# INFO:tensorflow:Step 27900 per-step time 0.594s
# I0509 18:01:44.956645 140465385244544 model_lib_v2.py:707] Step 27900 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.2890956,
#  'Loss/localization_loss': 0.3801622,
#  'Loss/regularization_loss': 0.14900722,
#  'Loss/total_loss': 0.818265,
#  'learning_rate': 0.0011454199}
# I0509 18:01:44.956903 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.2890956,
#  'Loss/localization_loss': 0.3801622,
#  'Loss/regularization_loss': 0.14900722,
#  'Loss/total_loss': 0.818265,
#  'learning_rate': 0.0011454199}
# INFO:tensorflow:Step 28000 per-step time 0.594s
# I0509 18:02:44.352675 140465385244544 model_lib_v2.py:707] Step 28000 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.28346953,
#  'Loss/localization_loss': 0.46678948,
#  'Loss/regularization_loss': 0.14888766,
#  'Loss/total_loss': 0.8991467,
#  'learning_rate': 0.0010393917}
# I0509 18:02:44.352988 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.28346953,
#  'Loss/localization_loss': 0.46678948,
#  'Loss/regularization_loss': 0.14888766,
#  'Loss/total_loss': 0.8991467,
#  'learning_rate': 0.0010393917}
# INFO:tensorflow:Step 28100 per-step time 0.603s
# I0509 18:03:44.622253 140465385244544 model_lib_v2.py:707] Step 28100 per-step time 0.603s
# INFO:tensorflow:{'Loss/classification_loss': 0.21011716,
#  'Loss/localization_loss': 0.16810149,
#  'Loss/regularization_loss': 0.14877868,
#  'Loss/total_loss': 0.5269973,
#  'learning_rate': 0.0009384508}
# I0509 18:03:44.622527 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.21011716,
#  'Loss/localization_loss': 0.16810149,
#  'Loss/regularization_loss': 0.14877868,
#  'Loss/total_loss': 0.5269973,
#  'learning_rate': 0.0009384508}
# INFO:tensorflow:Step 28200 per-step time 0.593s
# I0509 18:04:43.945912 140465385244544 model_lib_v2.py:707] Step 28200 per-step time 0.593s
# INFO:tensorflow:{'Loss/classification_loss': 0.4870506,
#  'Loss/localization_loss': 0.5930485,
#  'Loss/regularization_loss': 0.14867678,
#  'Loss/total_loss': 1.2287759,
#  'learning_rate': 0.0008426066}
# I0509 18:04:43.946249 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.4870506,
#  'Loss/localization_loss': 0.5930485,
#  'Loss/regularization_loss': 0.14867678,
#  'Loss/total_loss': 1.2287759,
#  'learning_rate': 0.0008426066}
# INFO:tensorflow:Step 28300 per-step time 0.593s
# I0509 18:05:43.233039 140465385244544 model_lib_v2.py:707] Step 28300 per-step time 0.593s
# INFO:tensorflow:{'Loss/classification_loss': 0.2900533,
#  'Loss/localization_loss': 0.3183205,
#  'Loss/regularization_loss': 0.1485917,
#  'Loss/total_loss': 0.7569655,
#  'learning_rate': 0.00075186865}
# I0509 18:05:43.233339 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.2900533,
#  'Loss/localization_loss': 0.3183205,
#  'Loss/regularization_loss': 0.1485917,
#  'Loss/total_loss': 0.7569655,
#  'learning_rate': 0.00075186865}
# INFO:tensorflow:Step 28400 per-step time 0.594s
# I0509 18:06:42.657389 140465385244544 model_lib_v2.py:707] Step 28400 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.35236573,
#  'Loss/localization_loss': 0.32973066,
#  'Loss/regularization_loss': 0.14851026,
#  'Loss/total_loss': 0.83060664,
#  'learning_rate': 0.00066625373}
# I0509 18:06:42.657662 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.35236573,
#  'Loss/localization_loss': 0.32973066,
#  'Loss/regularization_loss': 0.14851026,
#  'Loss/total_loss': 0.83060664,
#  'learning_rate': 0.00066625373}
# INFO:tensorflow:Step 28500 per-step time 0.594s
# I0509 18:07:42.025543 140465385244544 model_lib_v2.py:707] Step 28500 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.24979731,
#  'Loss/localization_loss': 0.329187,
#  'Loss/regularization_loss': 0.14844078,
#  'Loss/total_loss': 0.7274251,
#  'learning_rate': 0.0005857713}
# I0509 18:07:42.025799 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.24979731,
#  'Loss/localization_loss': 0.329187,
#  'Loss/regularization_loss': 0.14844078,
#  'Loss/total_loss': 0.7274251,
#  'learning_rate': 0.0005857713}
# INFO:tensorflow:Step 28600 per-step time 0.595s
# I0509 18:08:41.552606 140465385244544 model_lib_v2.py:707] Step 28600 per-step time 0.595s
# INFO:tensorflow:{'Loss/classification_loss': 0.2663192,
#  'Loss/localization_loss': 0.28509986,
#  'Loss/regularization_loss': 0.14837612,
#  'Loss/total_loss': 0.6997951,
#  'learning_rate': 0.00051043567}
# I0509 18:08:41.552882 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.2663192,
#  'Loss/localization_loss': 0.28509986,
#  'Loss/regularization_loss': 0.14837612,
#  'Loss/total_loss': 0.6997951,
#  'learning_rate': 0.00051043567}
# INFO:tensorflow:Step 28700 per-step time 0.593s
# I0509 18:09:40.851726 140465385244544 model_lib_v2.py:707] Step 28700 per-step time 0.593s
# INFO:tensorflow:{'Loss/classification_loss': 0.43177113,
#  'Loss/localization_loss': 0.43602863,
#  'Loss/regularization_loss': 0.14832059,
#  'Loss/total_loss': 1.0161203,
#  'learning_rate': 0.00044024925}
# I0509 18:09:40.851999 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.43177113,
#  'Loss/localization_loss': 0.43602863,
#  'Loss/regularization_loss': 0.14832059,
#  'Loss/total_loss': 1.0161203,
#  'learning_rate': 0.00044024925}
# INFO:tensorflow:Step 28800 per-step time 0.594s
# I0509 18:10:40.269053 140465385244544 model_lib_v2.py:707] Step 28800 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.30510455,
#  'Loss/localization_loss': 0.35204723,
#  'Loss/regularization_loss': 0.14827448,
#  'Loss/total_loss': 0.8054263,
#  'learning_rate': 0.00037522393}
# I0509 18:10:40.269351 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.30510455,
#  'Loss/localization_loss': 0.35204723,
#  'Loss/regularization_loss': 0.14827448,
#  'Loss/total_loss': 0.8054263,
#  'learning_rate': 0.00037522393}
# INFO:tensorflow:Step 28900 per-step time 0.593s
# I0509 18:11:39.605238 140465385244544 model_lib_v2.py:707] Step 28900 per-step time 0.593s
# INFO:tensorflow:{'Loss/classification_loss': 0.38858193,
#  'Loss/localization_loss': 0.5965386,
#  'Loss/regularization_loss': 0.14823508,
#  'Loss/total_loss': 1.1333556,
#  'learning_rate': 0.00031537167}
# I0509 18:11:39.605500 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.38858193,
#  'Loss/localization_loss': 0.5965386,
#  'Loss/regularization_loss': 0.14823508,
#  'Loss/total_loss': 1.1333556,
#  'learning_rate': 0.00031537167}
# INFO:tensorflow:Step 29000 per-step time 0.595s
# I0509 18:12:39.100484 140465385244544 model_lib_v2.py:707] Step 29000 per-step time 0.595s
# INFO:tensorflow:{'Loss/classification_loss': 0.26241285,
#  'Loss/localization_loss': 0.29546708,
#  'Loss/regularization_loss': 0.14820553,
#  'Loss/total_loss': 0.70608544,
#  'learning_rate': 0.00026069718}
# I0509 18:12:39.100789 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.26241285,
#  'Loss/localization_loss': 0.29546708,
#  'Loss/regularization_loss': 0.14820553,
#  'Loss/total_loss': 0.70608544,
#  'learning_rate': 0.00026069718}
# INFO:tensorflow:Step 29100 per-step time 0.594s
# I0509 18:13:38.500322 140465385244544 model_lib_v2.py:707] Step 29100 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.3523066,
#  'Loss/localization_loss': 0.36833945,
#  'Loss/regularization_loss': 0.14817786,
#  'Loss/total_loss': 0.8688239,
#  'learning_rate': 0.00021121008}
# I0509 18:13:38.500601 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.3523066,
#  'Loss/localization_loss': 0.36833945,
#  'Loss/regularization_loss': 0.14817786,
#  'Loss/total_loss': 0.8688239,
#  'learning_rate': 0.00021121008}
# INFO:tensorflow:Step 29200 per-step time 0.593s
# I0509 18:14:37.804045 140465385244544 model_lib_v2.py:707] Step 29200 per-step time 0.593s
# INFO:tensorflow:{'Loss/classification_loss': 0.47576562,
#  'Loss/localization_loss': 0.5034791,
#  'Loss/regularization_loss': 0.14815487,
#  'Loss/total_loss': 1.1273996,
#  'learning_rate': 0.00016691267}
# I0509 18:14:37.804315 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.47576562,
#  'Loss/localization_loss': 0.5034791,
#  'Loss/regularization_loss': 0.14815487,
#  'Loss/total_loss': 1.1273996,
#  'learning_rate': 0.00016691267}
# INFO:tensorflow:Step 29300 per-step time 0.594s
# I0509 18:15:37.171139 140465385244544 model_lib_v2.py:707] Step 29300 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.33310804,
#  'Loss/localization_loss': 0.33155918,
#  'Loss/regularization_loss': 0.14813694,
#  'Loss/total_loss': 0.8128042,
#  'learning_rate': 0.00012781215}
# I0509 18:15:37.171398 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.33310804,
#  'Loss/localization_loss': 0.33155918,
#  'Loss/regularization_loss': 0.14813694,
#  'Loss/total_loss': 0.8128042,
#  'learning_rate': 0.00012781215}
# INFO:tensorflow:Step 29400 per-step time 0.595s
# I0509 18:16:36.694258 140465385244544 model_lib_v2.py:707] Step 29400 per-step time 0.595s
# INFO:tensorflow:{'Loss/classification_loss': 0.27147734,
#  'Loss/localization_loss': 0.27390042,
#  'Loss/regularization_loss': 0.14812315,
#  'Loss/total_loss': 0.6935009,
#  'learning_rate': 9.3915645e-05}
# I0509 18:16:36.694541 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.27147734,
#  'Loss/localization_loss': 0.27390042,
#  'Loss/regularization_loss': 0.14812315,
#  'Loss/total_loss': 0.6935009,
#  'learning_rate': 9.3915645e-05}
# INFO:tensorflow:Step 29500 per-step time 0.594s
# I0509 18:17:36.048120 140465385244544 model_lib_v2.py:707] Step 29500 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.4117719,
#  'Loss/localization_loss': 0.35381162,
#  'Loss/regularization_loss': 0.14811452,
#  'Loss/total_loss': 0.913698,
#  'learning_rate': 6.5227934e-05}
# I0509 18:17:36.048408 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.4117719,
#  'Loss/localization_loss': 0.35381162,
#  'Loss/regularization_loss': 0.14811452,
#  'Loss/total_loss': 0.913698,
#  'learning_rate': 6.5227934e-05}
# INFO:tensorflow:Step 29600 per-step time 0.594s
# I0509 18:18:35.471703 140465385244544 model_lib_v2.py:707] Step 29600 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.34240136,
#  'Loss/localization_loss': 0.3331091,
#  'Loss/regularization_loss': 0.14810799,
#  'Loss/total_loss': 0.8236185,
#  'learning_rate': 4.1749026e-05}
# I0509 18:18:35.472056 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.34240136,
#  'Loss/localization_loss': 0.3331091,
#  'Loss/regularization_loss': 0.14810799,
#  'Loss/total_loss': 0.8236185,
#  'learning_rate': 4.1749026e-05}
# INFO:tensorflow:Step 29700 per-step time 0.595s
# I0509 18:19:34.955840 140465385244544 model_lib_v2.py:707] Step 29700 per-step time 0.595s
# INFO:tensorflow:{'Loss/classification_loss': 0.30422792,
#  'Loss/localization_loss': 0.27297598,
#  'Loss/regularization_loss': 0.14810385,
#  'Loss/total_loss': 0.7253077,
#  'learning_rate': 2.3486062e-05}
# I0509 18:19:34.956118 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.30422792,
#  'Loss/localization_loss': 0.27297598,
#  'Loss/regularization_loss': 0.14810385,
#  'Loss/total_loss': 0.7253077,
#  'learning_rate': 2.3486062e-05}
# INFO:tensorflow:Step 29800 per-step time 0.594s
# I0509 18:20:34.379339 140465385244544 model_lib_v2.py:707] Step 29800 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.42542568,
#  'Loss/localization_loss': 0.31753647,
#  'Loss/regularization_loss': 0.14810175,
#  'Loss/total_loss': 0.89106387,
#  'learning_rate': 1.0439045e-05}
# I0509 18:20:34.379640 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.42542568,
#  'Loss/localization_loss': 0.31753647,
#  'Loss/regularization_loss': 0.14810175,
#  'Loss/total_loss': 0.89106387,
#  'learning_rate': 1.0439045e-05}
# INFO:tensorflow:Step 29900 per-step time 0.594s
# I0509 18:21:33.775259 140465385244544 model_lib_v2.py:707] Step 29900 per-step time 0.594s
# INFO:tensorflow:{'Loss/classification_loss': 0.2981102,
#  'Loss/localization_loss': 0.40742907,
#  'Loss/regularization_loss': 0.14810099,
#  'Loss/total_loss': 0.8536402,
#  'learning_rate': 2.6103571e-06}
# I0509 18:21:33.775535 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.2981102,
#  'Loss/localization_loss': 0.40742907,
#  'Loss/regularization_loss': 0.14810099,
#  'Loss/total_loss': 0.8536402,
#  'learning_rate': 2.6103571e-06}
# INFO:tensorflow:Step 30000 per-step time 0.593s
# I0509 18:22:33.105791 140465385244544 model_lib_v2.py:707] Step 30000 per-step time 0.593s
# INFO:tensorflow:{'Loss/classification_loss': 0.29970738,
#  'Loss/localization_loss': 0.3151752,
#  'Loss/regularization_loss': 0.14810088,
#  'Loss/total_loss': 0.76298344,
#  'learning_rate': 0.0}
# I0509 18:22:33.106066 140465385244544 model_lib_v2.py:708] {'Loss/classification_loss': 0.29970738,
#  'Loss/localization_loss': 0.3151752,
#  'Loss/regularization_loss': 0.14810088,
#  'Loss/total_loss': 0.76298344,
#  'learning_rate': 0.0}

# %% [markdown]
# ##Validation

# %%
# !python model_main_tf2.py --model_dir=$current_dir --pipeline_config_path=$pipeline_config_path --checkpoint_dir=$current_dir
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0509 19:18:44.788326 139739611060096 model_lib_v2.py:1090] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0509 19:18:44.788516 139739611060096 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I
139739611060096 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.359987
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.440649
# I0509 19:27:15.211902 139739611060096 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.440649
# INFO:tensorflow:	+ Loss/localization_loss: 0.415586
# I0509 19:27:15.212823 139739611060096 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.415586
# INFO:tensorflow:	+ Loss/classification_loss: 0.359886
# I0509 19:27:15.213757 139739611060096 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.359886
# INFO:tensorflow:	+ Loss/regularization_loss: 0.148101
# I0509 19:27:15.214705 139739611060096 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.148101
# INFO:tensorflow:	+ Loss/total_loss: 0.923573
# I0509 19:27:15.215632 139739611060096 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.923573
# INFO:tensorflow:Exiting evaluation at step 30000
# I0509 19:27:15.327035 139739611060096 model_lib_v2.py:1180] Exiting evaluation at step 30000

# %% [markdown]
# # Export model
#
# export the model

# %%
#create exported directory
# !mkdir $output_directory

# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path $pipeline_config_path --trained_checkpoint_dir $current_dir --output_directory $exported_dir
# Out:
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/experiments_data/experiment2/exported’: File exists
# 2022-05-09 19:40:59.601121: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0509 19:40:59.735445 140042423646080 deprecation.py:615] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# 2022-05-09 19:41:15.480283: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f5d1453c290>, because it is not built.
# W0509 19:41:18.420788 140042423646080 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f5d1453c290>, because it is not built.
# W0509 19:41:34.753649 140042423646080 save.py:265] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 210). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/experiments_data/experiment2/exported/saved_model/assets
# I0509 19:41:40.713301 140042423646080 builder_impl.py:780] Assets written to: /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/experiments_data/experiment2/exported/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/experiments_data/experiment2/exported/pipeline.config
# I0509 19:41:41.302576 140042423646080 config_util.py:254] Writing pipeline config file to /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/experiments_data/experiment2/exported/pipeline.config

# %% [markdown]
# ## Exporting animation
#
# we create a video on the test set to assess performances

# %%
# %cd ..
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/Udacity-SDC1-Object-Detection-In-Urban-Environment/home/workspace

# %%
# !python inference_video.py --labelmap_path $label_map --model_path $saved_model_dir  --tf_record_path $tfrecord_test --config_path $pipeline_config_path --output_path $animation_path
# Out:
# 2022-05-09 19:42:41,302 INFO     Loading model from /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/experiments_data/experiment2/exported/saved_model
# 2022-05-09 19:42:42.386503: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-05-09 19:42:51,845 INFO     Loading config from experiments/experiment2/pipeline_new.config
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# 2022-05-09 19:42:53,722 INFO     Inference on /content/gdrive/MyDrive/Colab Notebooks/UDACITY-Self_Driving_Cars_Nanodegree/Project1-Object_detection_in_urban_environment/data/waymo/test/segment-12200383401366682847_2552_140_2572_140_with_camera_labels.tfrecord
# 2022-05-09 19:42:55,269 INFO     Step: 0
# 2022-05-09 19:43:00,093 INFO     Step: 10
# 2022-05-09 19:43:00,821 INFO     Step: 20
# 2022-05-09 19:43:01,561 INFO     Step: 30
# 2022-05-09 19:43:02,277 INFO     Step: 40
# 2022-05-09 19:43:02,953 INFO     Step: 50
# 2022-05-09 19:43:03,589 INFO     Step: 60
# 2022-05-09 19:43:04,226 INFO     Step: 70
# 2022-05-09 19:43:04,871 INFO     Step: 80
# 2022-05-09 19:43:05,518 INFO     Step: 90
# 2022-05-09 19:43:06,178 INFO     Step: 100
# 2022-05-09 19:43:06,845 INFO     Step: 110
# 2022-05-09 19:43:07,487 INFO     Step: 120
# 2022-05-09 19:43:08,156 INFO     Step: 130
# 2022-05-09 19:43:08,823 INFO     Step: 140
# 2022-05-09 19:43:09,494 INFO     Step: 150
# 2022-05-09 19:43:10,172 INFO     Step: 160
# 2022-05-09 19:43:10,840 INFO     Step: 170
# 2022-05-09 19:43:11,509 INFO     Step: 180
# 2022-05-09 19:43:12,192 INFO     Step: 190
